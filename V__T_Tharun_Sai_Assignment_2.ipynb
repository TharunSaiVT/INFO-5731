# %% [markdown]
# <a href="https://colab.research.google.com/github/TharunSaiVT/INFO-5731/blob/main/V__T_Tharun_Sai_Assignment_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
# !pip install semanticscholar
# Out:
# Requirement already satisfied: semanticscholar in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from semanticscholar) (8.2.3)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from semanticscholar) (0.27.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from semanticscholar) (1.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->semanticscholar) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->semanticscholar) (1.2.0)

# %%
import pandas as pd
import warnings
import time
from semanticscholar import SemanticScholar

# Ignoring warnings
warnings.filterwarnings("ignore")
pd.set_option('display.width', None)

# Initialization
sem_sch = SemanticScholar()

# Function to fetch abstracts iteratively
def fetch_abstracts(keywords, count):
    total_abstracts = []
    offset = 0
    while count > 0:
        for keyword in keywords:
            start_time = time.time()
            res = sem_sch.search_paper([keyword], fields=['abstract'])
            for paper in res:
                total_abstracts.append({'abstract': paper.abstract})
                count -= 1
                if count == 0:
                    break
                # Check if time limit (10 seconds) is exceeded
                if time.time() - start_time > 10:
                    break
            if count == 0:
                break
        offset += 1
    return total_abstracts

# Search articles using multiple topics and fetch 10000 abstracts
abstracts = fetch_abstracts(['machine learning', 'data science', 'artificial intelligence', 'information extraction'], 10000)

# Create DataFrame
df_paper = pd.DataFrame(abstracts)

# Save to CSV
df_paper.to_csv('output.csv', index=False)

# Print DataFrame
print(df_paper)
# Out:
#                                                abstract
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
# [10000 rows x 1 columns]

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import pandas as pd
import re
import warnings
from semanticscholar import SemanticScholar


# Function to clean text by removing special characters and punctuations
def clean_text(text):
    if text is None:
        return ''
    # Remove special characters and punctuations using regular expressions
    cleaned_text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    return cleaned_text

# Clean the abstracts and save the clean data in a new column
df_paper['cleaned_abstract'] = df_paper['abstract'].apply(clean_text)

# Save DataFrame to CSV with both original and cleaned abstracts
df_paper.to_csv('output_with_cleaned_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
#                                        cleaned_abstract
# 0     We present FashionMNIST a new dataset comprisi...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
# [10000 rows x 2 columns]

# %%
import pandas as pd
import re
import warnings
from semanticscholar import SemanticScholar


# Function to clean text by removing numbers
def clean_text(text):
    if text is None:
        return ''
    # Remove numbers using regular expressions
    cleaned_text = ''.join([i for i in text if not i.isdigit()])
    return cleaned_text

# Clean the abstracts and save the clean data in a new column
df_paper['cleaned_abstract'] = df_paper['abstract'].apply(clean_text)

# Save DataFrame to CSV with both original and cleaned abstracts
df_paper.to_csv('output_with_cleaned_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
#                                        cleaned_abstract
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
# [10000 rows x 2 columns]

# %%
import pandas as pd
import re
import warnings
from semanticscholar import SemanticScholar


# Function to lower the text
def clean_text(text):
    if text is None:
        return ''
    # functions to lowercase all the letters
    cleaned_text = text.lower()
    return cleaned_text

# Clean the abstracts and save the clean data in a new column
df_paper['cleaned_abstract'] = df_paper['abstract'].apply(clean_text)

# Save DataFrame to CSV with both original and cleaned abstracts
df_paper.to_csv('output_with_cleaned_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
#                                        cleaned_abstract
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  the image displayed in computed tomography is ...
# 9996  automatically acquiring synonymous collocation...
# 9997  the past decade has seen an explosion in the a...
# 9998  we have recently completed the sixth in a seri...
# 9999  face is a complex multidimensional visual mode...
#
# [10000 rows x 2 columns]

# %%
import pandas as pd
import re
import warnings
import nltk
from semanticscholar import SemanticScholar
from nltk.corpus import stopwords


stop_words = set(stopwords.words('english'))

# Function to clean text by removing stopwords
def remove_stopwords(text):
    if text is None:
        return ''
    # Tokenize the text
    words = text.split()
    # Remove stopwords
    filtered_words = [word for word in words if word.lower() not in stop_words]
    # Join the filtered words back into a string
    cleaned_text = ' '.join(filtered_words)
    return cleaned_text

# Clean the abstracts by removing stopwords and save the clean data in a new column
df_paper['abstract_without_stopwords'] = df_paper['abstract'].apply(remove_stopwords)

# Save DataFrame to CSV with both original and cleaned abstracts
df_paper.to_csv('output_without_stopwords.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
#                                        cleaned_abstract  \
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  the image displayed in computed tomography is ...
# 9996  automatically acquiring synonymous collocation...
# 9997  the past decade has seen an explosion in the a...
# 9998  we have recently completed the sixth in a seri...
# 9999  face is a complex multidimensional visual mode...
#
#                              abstract_without_stopwords
# 0     present Fashion-MNIST, new dataset comprising ...
# 1     TensorFlow machine learning system operates la...
# 2     TensorFlow interface expressing machine learni...
# 3     goal precipitation nowcasting predict future r...
# 4
# ...                                                 ...
# 9995  image displayed computed tomography scaled rep...
# 9996  Automatically acquiring synonymous collocation...
# 9997  past decade seen explosion amount digital info...
# 9998  recently completed sixth series "Message Under...
# 9999  Face complex multidimensional visual model dev...
#
# [10000 rows x 3 columns]

# %%
import pandas as pd
import re
import warnings
import nltk
from semanticscholar import SemanticScholar
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Create a stemmer object
porter_stemmer = PorterStemmer()

# Function to perform stemming on text
def perform_stemming(text):
    if text is None:
        return ''
    # Tokenize the text
    words = word_tokenize(text)
    # Perform stemming on each word
    stemmed_words = [porter_stemmer.stem(word) for word in words]
    # Join the stemmed words back into a string
    stemmed_text = ' '.join(stemmed_words)
    return stemmed_text

# Perform stemming on the abstracts and save the clean data in a new column
df_paper['stemmed_abstract'] = df_paper['abstract'].apply(perform_stemming)

# Save DataFrame to CSV with both original and stemmed abstracts
df_paper.to_csv('output_with_stemmed_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
#                                        cleaned_abstract  \
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  the image displayed in computed tomography is ...
# 9996  automatically acquiring synonymous collocation...
# 9997  the past decade has seen an explosion in the a...
# 9998  we have recently completed the sixth in a seri...
# 9999  face is a complex multidimensional visual mode...
#
#                              abstract_without_stopwords  \
# 0     present Fashion-MNIST, new dataset comprising ...
# 1     TensorFlow machine learning system operates la...
# 2     TensorFlow interface expressing machine learni...
# 3     goal precipitation nowcasting predict future r...
# 4
# ...                                                 ...
# 9995  image displayed computed tomography scaled rep...
# 9996  Automatically acquiring synonymous collocation...
# 9997  past decade seen explosion amount digital info...
# 9998  recently completed sixth series "Message Under...
# 9999  Face complex multidimensional visual model dev...
#
#                                        stemmed_abstract
# 0     we present fashion-mnist , a new dataset compr...
# 1     tensorflow is a machin learn system that oper ...
# 2     tensorflow is an interfac for express machin l...
# 3     the goal of precipit nowcast is to predict the...
# 4
# ...                                                 ...
# 9995  the imag display in comput tomographi is a sca...
# 9996  automat acquir synonym colloc pair such as and...
# 9997  the past decad ha seen an explos in the amount...
# 9998  we have recent complet the sixth in a seri of ...
# 9999  face is a complex multidimension visual model ...
#
# [10000 rows x 4 columns]

# %%
import pandas as pd
import re
import warnings
import nltk
from semanticscholar import SemanticScholar
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Create a lemmatizer object
lemmatizer = WordNetLemmatizer()

# Function to perform lemmatization on text
def perform_lemmatization(text):
    if text is None:
        return ''
    # Tokenize the text
    words = word_tokenize(text)
    # Perform lemmatization on each word
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    # Join the lemmatized words back into a string
    lemmatized_text = ' '.join(lemmatized_words)
    return lemmatized_text

# Perform lemmatization on the abstracts and save the clean data in a new column
df_paper['lemmatized_abstract'] = df_paper['abstract'].apply(perform_lemmatization)

# Save DataFrame to CSV with both original and lemmatized abstracts
df_paper.to_csv('output_with_lemmatized_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
#                                        cleaned_abstract  \
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  the image displayed in computed tomography is ...
# 9996  automatically acquiring synonymous collocation...
# 9997  the past decade has seen an explosion in the a...
# 9998  we have recently completed the sixth in a seri...
# 9999  face is a complex multidimensional visual mode...
#
#                              abstract_without_stopwords  \
# 0     present Fashion-MNIST, new dataset comprising ...
# 1     TensorFlow machine learning system operates la...
# 2     TensorFlow interface expressing machine learni...
# 3     goal precipitation nowcasting predict future r...
# 4
# ...                                                 ...
# 9995  image displayed computed tomography scaled rep...
# 9996  Automatically acquiring synonymous collocation...
# 9997  past decade seen explosion amount digital info...
# 9998  recently completed sixth series "Message Under...
# 9999  Face complex multidimensional visual model dev...
#
#                                        stemmed_abstract  \
# 0     we present fashion-mnist , a new dataset compr...
# 1     tensorflow is a machin learn system that oper ...
# 2     tensorflow is an interfac for express machin l...
# 3     the goal of precipit nowcast is to predict the...
# 4
# ...                                                 ...
# 9995  the imag display in comput tomographi is a sca...
# 9996  automat acquir synonym colloc pair such as and...
# 9997  the past decad ha seen an explos in the amount...
# 9998  we have recent complet the sixth in a seri of ...
# 9999  face is a complex multidimension visual model ...
#
#                                     lemmatized_abstract
# 0     We present Fashion-MNIST , a new dataset compr...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade ha seen an explosion in the am...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
# [10000 rows x 5 columns]

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag
import spacy

# Load SpaCy English model for Named Entity Recognition
nlp = spacy.load("en_core_web_sm")

# Read the CSV file containing the clean text
try:
    df = pd.read_csv('output_with_lemmatized_abstract.csv')
except FileNotFoundError:
    print("File not found. Please ensure the file path is correct.")
    exit()
except Exception as e:
    print("An error occurred while reading the CSV file:", e)
    exit()

# Function to conduct Parts of Speech (POS) Tagging and calculate counts
def pos_tagging_and_count(text):
    nouns = verbs = adjectives = adverbs = 0
    if isinstance(text, str):  # Check if text is a string
        tokens = word_tokenize(text)
        pos_tags = pos_tag(tokens)
        for _, tag in pos_tags:
            if tag.startswith('N'):  # Noun
                nouns += 1
            elif tag.startswith('V'):  # Verb
                verbs += 1
            elif tag.startswith('J'):  # Adjective
                adjectives += 1
            elif tag.startswith('R'):  # Adverb
                adverbs += 1
    return nouns, verbs, adjectives, adverbs

# Function to perform Constituency Parsing and Dependency Parsing
def parse_trees(text):
    if isinstance(text, str):  # Check if text is a string
        sentences = sent_tokenize(text)
        for sentence in sentences:
            print("Constituency Parsing Tree:")
            parsed_sentence = nlp(sentence)
            for token in parsed_sentence:
                print(token.text, token.dep_, token.head.text, token.head.pos_,
                      [child for child in token.children])
            print("\nDependency Parsing Tree:")
            print(parsed_sentence)
            print("="*50)

# Function to perform Named Entity Recognition (NER) and calculate counts
def ner_and_count(text):
    entities = []
    if isinstance(text, str):  # Check if text is a string
        doc = nlp(text)
        for ent in doc.ents:
            entities.append(ent.text + " - " + ent.label_)
    return entities

# Apply functions to each row of the DataFrame
df['noun'], df['verb'], df['adjective'], df['adverb'] = zip(*df['lemmatized_abstract'].apply(pos_tagging_and_count))
df['lemmatized_abstract'].apply(parse_trees)
df['entities'] = df['lemmatized_abstract'].apply(ner_and_count)

# Display DataFrame with added columns
print(df)
# Out:
# Streaming output truncated to the last 5000 lines.
# private amod communication NOUN []
# communication pobj for ADP [private, between]
# between prep communication NOUN [device]
# two nummod device NOUN []
# wireless amod device NOUN []
# device pobj between ADP [two, wireless]
# , punct for ADP []
# from prep evaluate VERB [strength]
# the det strength NOUN []
# received amod strength NOUN []
# signal compound strength NOUN []
# strength pobj from ADP [the, received, signal, variation]
# ( punct variation NOUN []
# RSS nmod variation NOUN []
# ) punct variation NOUN []
# variation appos strength NOUN [(, RSS, ), on]
# on prep variation NOUN [channel]
# the det channel NOUN []
# wireless amod channel NOUN []
# channel pobj on ADP [the, wireless, between]
# between prep channel NOUN [device]
# the det device NOUN []
# two nummod device NOUN []
# device pobj between ADP [the, two]
# . punct evaluate VERB []
#
# Dependency Parsing Tree:
# We evaluate the effectiveness of secret key extraction , for private communication between two wireless device , from the received signal strength ( RSS ) variation on the wireless channel between the two device .
# ==================================================
# Constituency Parsing Tree:
# We nsubj use VERB []
# use ROOT use VERB [We, measurement, in, .]
# real amod measurement NOUN []
# world compound measurement NOUN []
# measurement dobj use VERB [real, world, of]
# of prep measurement NOUN [RSS]
# RSS pobj of ADP []
# in prep use VERB [variety, and, setting]
# a det variety NOUN []
# variety pobj in ADP [a, of]
# of prep variety NOUN [environment]
# environment pobj of ADP []
# and cc in ADP []
# setting conj in ADP []
# . punct use VERB []
#
# Dependency Parsing Tree:
# We use real world measurement of RSS in a variety of environment and setting .
# ==================================================
# Constituency Parsing Tree:
# The det result NOUN []
# result nsubj show NOUN [The, from, with]
# from prep result NOUN [experiment]
# our poss experiment NOUN []
# experiment pobj from ADP [our]
# with prep result NOUN []
# 802.11 npadvmod based VERB []
# - punct based VERB []
# based amod laptop NOUN [802.11, -]
# laptop compound show NOUN [based]
# show ROOT show NOUN [result, laptop, cause, and/or, obtained, .]
# that mark have VERB []
# in prep have VERB [environment]
# certain amod environment NOUN []
# environment pobj in ADP [certain]
# , punct have VERB []
# due prep have VERB [to, lack]
# to pcomp due ADP []
# lack pobj due ADP [of]
# of prep lack NOUN [variation]
# variation pobj of ADP [in]
# in prep variation NOUN [channel]
# the det channel NOUN []
# wireless amod channel NOUN []
# channel pobj in ADP [the, wireless]
# , punct have VERB []
# the det bit NOUN []
# extracted amod bit NOUN []
# bit nsubj have VERB [the, extracted]
# have advcl cause VERB [that, in, ,, due, ,, bit, entropy]
# very advmod low ADJ []
# low amod entropy NOUN [very]
# entropy dobj have VERB [low, making]
# making acl entropy NOUN [unsuitable, for]
# these det bit NOUN []
# bit npadvmod unsuitable ADJ [these]
# unsuitable acomp making VERB [bit]
# for prep making VERB [key]
# a det key NOUN []
# secret amod key NOUN []
# key pobj for ADP [a, secret]
# , punct cause VERB []
# an det adversary NOUN []
# adversary nsubj cause VERB [an]
# can aux cause VERB []
# cause ccomp show NOUN [have, ,, adversary, can, generation, ,, and, in]
# predictable amod generation NOUN []
# key amod generation NOUN []
# generation dobj cause VERB [predictable, key, in]
# in prep generation NOUN [environment]
# these det environment NOUN []
# static amod environment NOUN []
# environment pobj in ADP [these, static]
# , punct cause VERB []
# and cc cause VERB []
# in conj cause VERB [scenario, ,]
# dynamic amod scenario NOUN []
# scenario pobj in ADP [dynamic, are]
# where advmod are AUX []
# the det device NOUN []
# two nummod device NOUN []
# device nsubj are AUX [the, two]
# are relcl scenario NOUN [where, device, mobile]
# mobile acomp are AUX []
# , punct in ADP []
# and/or cc show NOUN []
# where advmod is VERB []
# there expl is VERB []
# is advcl obtained VERB [where, there, movement]
# a det movement NOUN []
# significant amod movement NOUN []
# movement attr is VERB [a, significant, in]
# in prep movement NOUN [environment]
# the det environment NOUN []
# environment pobj in ADP [the]
# , punct obtained VERB []
# high amod bit NOUN []
# entropy compound bit NOUN []
# bit nsubjpass obtained VERB [high, entropy]
# are auxpass obtained VERB []
# obtained conj show NOUN [is, ,, bit, are, quickly]
# fairly advmod quickly ADV []
# quickly advmod obtained VERB [fairly]
# . punct show NOUN []
#
# Dependency Parsing Tree:
# The result from our experiment with 802.11-based laptop show that in certain environment , due to lack of variation in the wireless channel , the extracted bit have very low entropy making these bit unsuitable for a secret key , an adversary can cause predictable key generation in these static environment , and in dynamic scenario where the two device are mobile , and/or where there is a significant movement in the environment , high entropy bit are obtained fairly quickly .
# ==================================================
# Constituency Parsing Tree:
# Building advcl develop VERB [on]
# on prep Building VERB [strength]
# the det strength NOUN []
# strength pobj on ADP [the, of]
# of prep strength NOUN [approach]
# existing amod approach NOUN []
# secret amod approach NOUN []
# key amod approach NOUN []
# extraction compound approach NOUN []
# approach pobj of ADP [existing, secret, key, extraction]
# , punct develop VERB []
# we nsubj develop VERB []
# develop ROOT develop VERB [Building, ,, we, environment, scheme, .]
# an det environment NOUN []
# environment dobj develop VERB [an]
# adaptive amod scheme NOUN []
# secret amod scheme NOUN []
# key amod generation NOUN []
# generation compound scheme NOUN [key]
# scheme dobj develop VERB [adaptive, secret, generation, us]
# that nsubj us PRON []
# us relcl scheme NOUN [that, quantizer]
# an det quantizer NOUN []
# adaptive amod quantizer NOUN []
# lossy amod quantizer NOUN []
# quantizer attr us PRON [an, adaptive, lossy, in]
# in prep quantizer NOUN [conjunction]
# conjunction pobj in ADP [with]
# with prep conjunction NOUN [reconciliation]
# Cascade npadvmod based VERB []
# - punct based VERB []
# based amod reconciliation NOUN [Cascade, -]
# information compound reconciliation NOUN []
# reconciliation pobj with ADP [based, information, and, amplification]
# and cc reconciliation NOUN []
# privacy compound amplification NOUN []
# amplification conj reconciliation NOUN [privacy]
# . punct develop VERB []
#
# Dependency Parsing Tree:
# Building on the strength of existing secret key extraction approach , we develop an environment adaptive secret key generation scheme that us an adaptive lossy quantizer in conjunction with Cascade-based information reconciliation and privacy amplification .
# ==================================================
# Constituency Parsing Tree:
# Our poss measurement NOUN []
# measurement nsubj show VERB [Our]
# show ROOT show VERB [measurement, performs, .]
# that mark performs VERB []
# our poss scheme NOUN []
# scheme nsubj performs VERB [our]
# , punct performs VERB []
# in prep performs VERB [comparison]
# comparison pobj in ADP [to]
# to prep comparison NOUN [one]
# the det one NOUN []
# existing amod one NOUN []
# one pobj to ADP [the, existing, evaluate]
# that dobj evaluate VERB []
# we nsubj evaluate VERB []
# evaluate relcl one NOUN [that, we]
# , punct performs VERB []
# performs ccomp show VERB [that, scheme, ,, in, ,, best]
# the det best ADJ []
# best dobj performs VERB [the, in]
# in prep best ADJ [term]
# term pobj in ADP [of]
# of prep term NOUN [generating]
# generating pcomp of ADP [bit, at]
# high amod bit NOUN []
# entropy compound bit NOUN []
# bit dobj generating VERB [high, entropy]
# at prep generating VERB [rate]
# a det rate NOUN []
# high amod bit NOUN []
# bit compound rate NOUN [high]
# rate pobj at ADP [a, bit]
# . punct show VERB []
#
# Dependency Parsing Tree:
# Our measurement show that our scheme , in comparison to the existing one that we evaluate , performs the best in term of generating high entropy bit at a high bit rate .
# ==================================================
# Constituency Parsing Tree:
# The det stream NOUN []
# secret amod stream NOUN []
# key amod bit NOUN []
# bit compound stream NOUN [key]
# stream nsubj pas VERB [The, secret, bit, generated]
# generated acl stream NOUN [by]
# by agent generated VERB [scheme]
# our poss scheme NOUN []
# scheme pobj by ADP [our]
# also advmod pas VERB []
# pas ROOT pas VERB [stream, also, test, .]
# the det test NOUN []
# randomness compound test NOUN []
# test dobj pas VERB [the, randomness, of]
# of prep test NOUN [suite]
# the det suite NOUN []
# NIST compound suite NOUN []
# test compound suite NOUN []
# suite pobj of ADP [the, NIST, test, conduct]
# that dobj conduct VERB []
# we nsubj conduct VERB []
# conduct relcl suite NOUN [that, we]
# . punct pas VERB []
#
# Dependency Parsing Tree:
# The secret key bit stream generated by our scheme also pas the randomness test of the NIST test suite that we conduct .
# ==================================================
# Constituency Parsing Tree:
# We nsubj build VERB []
# also advmod build VERB []
# build ROOT build VERB [We, also, and, evaluate, .]
# and cc build VERB []
# evaluate conj build VERB [performance]
# the det performance NOUN []
# performance dobj evaluate VERB [the, of]
# of prep performance NOUN [extraction]
# secret amod extraction NOUN []
# key amod extraction NOUN []
# extraction pobj of ADP [secret, key, using]
# using acl extraction NOUN [phones]
# small amod devices NOUN []
# , punct devices NOUN []
# low amod power NOUN []
# - punct power NOUN []
# power nmod devices NOUN [low, -]
# , punct devices NOUN []
# hand npadvmod held VERB []
# - punct held VERB []
# held amod devices NOUN [hand, -]
# devices nmod phones NOUN [small, ,, power, ,, held, -, Nexus]
# - punct devices NOUN []
# Google compound Nexus PROPN []
# Nexus appos devices NOUN [Google]
# One nummod phones NOUN []
# phones dobj using VERB [devices, One, -, equipped]
# - punct phones NOUN []
# that nsubjpass equipped VERB []
# are auxpass equipped VERB []
# equipped relcl phones NOUN [that, are, card]
# 802.11 nummod card NOUN []
# wireless amod card NOUN []
# network compound card NOUN []
# card dobj equipped VERB [802.11, wireless, network]
# . punct build VERB []
#
# Dependency Parsing Tree:
# We also build and evaluate the performance of secret key extraction using small , low-power , hand-held devices-Google Nexus One phones-that are equipped 802.11 wireless network card .
# ==================================================
# Constituency Parsing Tree:
# Last advmod evaluate VERB []
# , punct evaluate VERB []
# we nsubj evaluate VERB []
# evaluate ROOT evaluate VERB [Last, ,, we, extraction, .]
# secret amod extraction NOUN []
# key amod extraction NOUN []
# extraction dobj evaluate VERB [secret, key, in, testbed]
# in prep extraction NOUN [network]
# a det output NOUN []
# multiple amod output NOUN []
# input nmod output NOUN []
# multiple amod output NOUN []
# output nmod network NOUN [a, multiple, input, multiple]
# ( punct -like ADJ []
# MIMO nmod -like ADJ []
# ) punct -like ADJ []
# -like amod network NOUN [(, MIMO, )]
# sensor compound network NOUN []
# network pobj in ADP [output, -like, sensor]
# testbed acl extraction NOUN [create]
# that mark create VERB []
# we nsubj create VERB []
# create ccomp testbed VERB [that, we, using]
# using xcomp create VERB [node]
# multiple amod sensor NOUN []
# TelosB punct sensor NOUN []
# sensor compound node PROPN [multiple, TelosB]
# node dobj using VERB [sensor]
# . punct evaluate VERB []
#
# Dependency Parsing Tree:
# Last , we evaluate secret key extraction in a multiple input multiple output ( MIMO ) -like sensor network testbed that we create using multiple TelosB sensor node .
# ==================================================
# Constituency Parsing Tree:
# We nsubj find VERB []
# find ROOT find VERB [We, produce, .]
# that mark produce VERB []
# our poss environment NOUN []
# MIMO npadvmod like ADJ []
# - punct like ADJ []
# like amod environment NOUN [MIMO, -]
# sensor compound environment NOUN []
# environment nsubj produce VERB [our, like, sensor]
# produce ccomp find VERB [that, environment, prohibitively, mismatch]
# prohibitively advmod produce VERB []
# high amod bit NOUN []
# bit compound mismatch NOUN [high]
# mismatch dobj produce VERB [bit, ,, address]
# , punct mismatch NOUN []
# which dobj address VERB []
# we nsubj address VERB []
# address relcl mismatch NOUN [which, we, using]
# using xcomp address VERB [stage]
# an det stage NOUN []
# iterative amod stage NOUN []
# distillation compound stage NOUN []
# stage dobj using VERB [an, iterative, distillation, add]
# that dobj add VERB []
# we nsubj add VERB []
# add relcl stage NOUN [that, we, to]
# to prep add VERB [process]
# the det process NOUN []
# key amod process NOUN []
# extraction compound process NOUN []
# process pobj to ADP [the, key, extraction]
# . punct find VERB []
#
# Dependency Parsing Tree:
# We find that our MIMO-like sensor environment produce prohibitively high bit mismatch , which we address using an iterative distillation stage that we add to the key extraction process .
# ==================================================
# Constituency Parsing Tree:
# Ultimately advmod show VERB []
# , punct show VERB []
# we nsubj show VERB []
# show ROOT show VERB [Ultimately, ,, we, increased, .]
# that mark increased VERB []
# the det rate NOUN []
# secret amod rate NOUN []
# key amod rate NOUN []
# generation compound rate NOUN []
# rate nsubjpass increased VERB [the, secret, key, generation]
# is auxpass increased VERB []
# increased ccomp show VERB [that, rate, is, involved]
# when advmod involved VERB []
# multiple amod sensor NOUN []
# sensor nsubjpass involved VERB [multiple]
# are auxpass involved VERB []
# involved advcl increased VERB [when, sensor, are, in]
# in prep involved VERB [process]
# the det process NOUN []
# key amod process NOUN []
# extraction compound process NOUN []
# process pobj in ADP [the, key, extraction]
# . punct show VERB []
#
# Dependency Parsing Tree:
# Ultimately , we show that the secret key generation rate is increased when multiple sensor are involved in the key extraction process .
# ==================================================
# Constituency Parsing Tree:
# We nsubj develop VERB []
# develop ROOT develop VERB [We, structure, based, .]
# finite amod structure NOUN []
# element compound structure NOUN []
# data compound structure NOUN []
# structure dobj develop VERB [finite, element, data, for]
# for prep structure NOUN [T‐splines]
# T‐splines pobj for ADP []
# based prep develop VERB [on]
# on prep based VERB [extraction]
# Bézier compound extraction NOUN []
# extraction pobj on ADP [Bézier, generalizing]
# generalizing acl extraction NOUN [work]
# our poss work NOUN []
# previous amod work NOUN []
# work dobj generalizing VERB [our, previous, for]
# for prep work NOUN [NURBS]
# NURBS pobj for ADP []
# . punct develop VERB []
#
# Dependency Parsing Tree:
# We develop finite element data structure for T‐splines based on Bézier extraction generalizing our previous work for NURBS .
# ==================================================
# Constituency Parsing Tree:
# As prep defined VERB [in]
# in prep As ADP [analysis]
# traditional amod analysis NOUN []
# finite amod element NOUN []
# element compound analysis NOUN [finite]
# analysis pobj in ADP [traditional, element]
# , punct defined VERB []
# the det element NOUN []
# extracted amod element NOUN []
# Bézier compound element NOUN []
# element nsubjpass defined VERB [the, extracted, Bézier, basis]
# are auxpass defined VERB []
# defined ROOT defined VERB [As, ,, element, are, in, ,, .]
# in prep defined VERB [term]
# term pobj in ADP [of]
# of prep term NOUN [set]
# a det set NOUN []
# fixed amod set NOUN []
# set pobj of ADP [a, fixed, of]
# of prep set NOUN [function]
# polynomial amod function NOUN []
# basis compound function NOUN []
# function pobj of ADP [polynomial, basis]
# , punct defined VERB []
# the det basis NOUN []
# so‐called amod basis NOUN []
# Bernstein compound basis NOUN []
# basis appos element NOUN [the, so‐called, Bernstein]
# . punct defined VERB []
#
# Dependency Parsing Tree:
# As in traditional finite element analysis , the extracted Bézier element are defined in term of a fixed set of polynomial basis function , the so‐called Bernstein basis .
# ==================================================
# Constituency Parsing Tree:
# The det element NOUN []
# Bézier compound element NOUN []
# element nsubjpass processed VERB [The, Bézier]
# may aux processed VERB []
# be auxpass processed VERB []
# processed ROOT processed VERB [element, may, be, in, a, in, ,, utilizing, .]
# in prep processed VERB [way]
# the det way NOUN []
# same amod way NOUN []
# way pobj in ADP [the, same]
# a npadvmod processed VERB []
# in prep processed VERB [program]
# a det program NOUN []
# standard amod program NOUN []
# finite amod element NOUN []
# element compound program NOUN [finite]
# computer compound program NOUN []
# program pobj in ADP [a, standard, element, computer]
# , punct processed VERB []
# utilizing advcl processed VERB [array]
# exactly advmod array NOUN []
# the det array NOUN []
# same amod array NOUN []
# data compound processing NOUN []
# processing compound array NOUN [data]
# array dobj utilizing VERB [exactly, the, same, processing]
# . punct processed VERB []
#
# Dependency Parsing Tree:
# The Bézier element may be processed in the same way a in a standard finite element computer program , utilizing exactly the same data processing array .
# ==================================================
# Constituency Parsing Tree:
# In prep need VERB [fact]
# fact pobj In ADP []
# , punct need VERB []
# only advmod subroutine NOUN []
# the det subroutine NOUN []
# shape compound function NOUN []
# function compound subroutine NOUN [shape]
# subroutine nsubj need VERB [only, the, function]
# need ROOT need VERB [In, ,, subroutine, modified, remain, .]
# to aux modified VERB []
# be auxpass modified VERB []
# modified xcomp need VERB [to, be]
# while mark remain VERB []
# all det aspect NOUN []
# other amod aspect NOUN []
# aspect nsubj remain VERB [all, other, of]
# of prep aspect NOUN [program]
# a det program NOUN []
# finite amod program NOUN []
# element compound program NOUN []
# program pobj of ADP [a, finite, element]
# remain advcl need VERB [while, aspect, same]
# the det same ADJ []
# same attr remain VERB [the]
# . punct need VERB []
#
# Dependency Parsing Tree:
# In fact , only the shape function subroutine need to be modified while all other aspect of a finite element program remain the same .
# ==================================================
# Constituency Parsing Tree:
# A det byproduct NOUN []
# byproduct nsubj is AUX [A, of]
# of prep byproduct NOUN [process]
# the det process NOUN []
# extraction compound process NOUN []
# process pobj of ADP [the, extraction]
# is ROOT is AUX [byproduct, operator, .]
# the det operator NOUN []
# element compound operator NOUN []
# extraction compound operator NOUN []
# operator attr is AUX [the, element, extraction]
# . punct is AUX []
#
# Dependency Parsing Tree:
# A byproduct of the extraction process is the element extraction operator .
# ==================================================
# Constituency Parsing Tree:
# This det operator NOUN []
# operator nsubj localizes VERB [This]
# localizes ROOT localizes VERB [operator, information, ,, and, represents, referred, .]
# the det information NOUN []
# topological amod information NOUN [and, global]
# and cc topological ADJ []
# global conj topological ADJ []
# smoothness amod information NOUN []
# information dobj localizes VERB [the, topological, smoothness, to]
# to prep information NOUN [level]
# the det level NOUN []
# element compound level NOUN []
# level pobj to ADP [the, element]
# , punct localizes VERB []
# and cc localizes VERB []
# represents conj localizes VERB [treatment]
# a det treatment NOUN []
# canonical amod treatment NOUN []
# treatment dobj represents VERB [a, canonical, of]
# of prep treatment NOUN [T‐junctions]
# T‐junctions pobj of ADP []
# , punct referred VERB []
# referred conj localizes VERB [,, to]
# to prep referred VERB [node]
# a det node NOUN []
# ‘ punct node NOUN []
# hanging amod node NOUN []
# node pobj to ADP [a, ‘, hanging, ’, in]
# ’ punct node NOUN []
# in prep node NOUN [analysis]
# finite amod analysis NOUN []
# element compound analysis NOUN []
# analysis pobj in ADP [finite, element, and, feature]
# and cc analysis NOUN []
# a det feature NOUN []
# fundamental amod feature NOUN []
# feature conj analysis NOUN [a, fundamental, of]
# of prep feature NOUN [T‐splines]
# T‐splines pobj of ADP []
# . punct localizes VERB []
#
# Dependency Parsing Tree:
# This operator localizes the topological and global smoothness information to the element level , and represents a canonical treatment of T‐junctions , referred to a ‘ hanging node ’ in finite element analysis and a fundamental feature of T‐splines .
# ==================================================
# Constituency Parsing Tree:
# A det example NOUN []
# detailed amod example NOUN []
# example nsubjpass presented VERB [A, detailed]
# is auxpass presented VERB []
# presented ROOT presented VERB [example, is, illustrate, .]
# to aux illustrate VERB []
# illustrate xcomp presented VERB [to, idea]
# the det idea NOUN []
# idea dobj illustrate VERB [the]
# . punct presented VERB []
#
# Dependency Parsing Tree:
# A detailed example is presented to illustrate the idea .
# ==================================================
# Constituency Parsing Tree:
# Copyright compound © NOUN []
# © ROOT © NOUN [Copyright, 2011, Wiley, .]
# 2011 nummod © NOUN []
# John compound Wiley PROPN []
# Wiley dobj © NOUN [John, &, Sons, Ltd]
# & cc Wiley PROPN []
# Sons conj Wiley PROPN []
# , punct Ltd PROPN []
# Ltd appos Wiley PROPN [,]
# . punct © NOUN []
#
# Dependency Parsing Tree:
# Copyright © 2011 John Wiley & Sons , Ltd .
# ==================================================
# Constituency Parsing Tree:
# Recognition nsubj is AUX [of, out]
# of prep Recognition NOUN [face]
# human amod face NOUN []
# face pobj of ADP [human]
# out prep Recognition NOUN [of]
# of prep out ADP [still, image]
# still pcomp of ADP []
# image pobj of ADP [or, sequence]
# or cc image NOUN []
# image compound sequence NOUN []
# sequence conj image NOUN [image]
# is ROOT is AUX [Recognition, field, .]
# a det field NOUN []
# research compound field NOUN []
# field attr is AUX [a, research, of]
# of prep field NOUN [interest]
# fast advmod increasing VERB []
# increasing amod interest NOUN [fast]
# interest pobj of ADP [increasing]
# . punct is AUX []
#
# Dependency Parsing Tree:
# Recognition of human face out of still image or image sequence is a research field of fast increasing interest .
# ==================================================
# Constituency Parsing Tree:
# At prep have VERB [first]
# first pcomp At ADP []
# , punct region NOUN []
# facial amod region NOUN []
# region nsubj have VERB [,, facial, and, feature]
# and cc region NOUN []
# facial amod feature NOUN []
# feature conj region NOUN [facial, like]
# like prep feature NOUN [eye]
# eye pobj like ADP [and, mouth]
# and cc eye NOUN []
# mouth conj eye NOUN []
# have ROOT have VERB [At, region, extracted, .]
# to aux extracted VERB []
# be auxpass extracted VERB []
# extracted xcomp have VERB [to, be]
# . punct have VERB []
#
# Dependency Parsing Tree:
# At first , facial region and facial feature like eye and mouth have to be extracted .
# ==================================================
# Constituency Parsing Tree:
# In prep propose VERB [paper]
# the det paper NOUN []
# present amod paper NOUN []
# paper pobj In ADP [the, present]
# we nsubj propose VERB []
# propose ROOT propose VERB [In, we, approach, .]
# an det approach NOUN []
# approach dobj propose VERB [an, cope]
# that nsubj cope VERB []
# cope relcl approach NOUN [that, with]
# with prep cope VERB [problem]
# problem pobj with ADP [of]
# of prep problem NOUN [step]
# these det step NOUN []
# first amod step NOUN []
# two nummod step NOUN []
# step pobj of ADP [these, first, two]
# . punct propose VERB []
#
# Dependency Parsing Tree:
# In the present paper we propose an approach that cope with problem of these first two step .
# ==================================================
# Constituency Parsing Tree:
# We nsubj perform VERB []
# perform ROOT perform VERB [We, localization, based, in, .]
# face compound localization NOUN []
# localization dobj perform VERB [face]
# based prep perform VERB [on]
# on prep based VERB [observation]
# the det observation NOUN []
# observation pobj on ADP [the, characterized]
# that mark characterized VERB []
# human amod face NOUN []
# face nsubjpass characterized VERB [human]
# are auxpass characterized VERB []
# characterized acl observation NOUN [that, face, are, by, ,]
# by agent characterized VERB [shape]
# their poss shape NOUN []
# oval compound shape NOUN []
# shape pobj by ADP [their, oval, and, color]
# and cc shape NOUN []
# skin compound color NOUN []
# - punct color NOUN []
# color conj shape NOUN [skin, -]
# , punct characterized VERB []
# also advmod in ADP []
# in prep perform VERB [also, case]
# the det case NOUN []
# case pobj in ADP [the, of]
# of prep case NOUN [condition]
# varying amod condition NOUN []
# light amod condition NOUN []
# condition pobj of ADP [varying, light]
# . punct perform VERB []
#
# Dependency Parsing Tree:
# We perform face localization based on the observation that human face are characterized by their oval shape and skin-color , also in the case of varying light condition .
# ==================================================
# Constituency Parsing Tree:
# For prep segment VERB [that]
# that pobj For ADP []
# we nsubj segment VERB []
# segment ROOT segment VERB [For, we, face, by, .]
# face dobj segment VERB []
# by prep segment VERB [evaluating]
# evaluating pcomp by ADP [information]
# shape nmod information NOUN [and, color]
# and cc shape NOUN []
# color conj shape NOUN []
# ( punct information NOUN []
# HSV nmod information NOUN []
# ) punct information NOUN []
# information dobj evaluating VERB [shape, (, HSV, )]
# . punct segment VERB []
#
# Dependency Parsing Tree:
# For that we segment face by evaluating shape and color ( HSV ) information .
# ==================================================
# Constituency Parsing Tree:
# Then advmod verified VERB []
# face nsubjpass verified VERB [hypothesis]
# hypothesis dobj face VERB []
# are auxpass verified VERB []
# verified ROOT verified VERB [Then, face, are, by, .]
# by agent verified VERB [searching]
# searching pcomp by ADP [for]
# for prep searching VERB [feature]
# facial amod feature NOUN []
# feature pobj for ADP [facial, inside]
# inside advmod feature NOUN [of]
# of prep inside ADV [region]
# the det region NOUN []
# face npadvmod like ADJ []
# - punct like ADJ []
# like amod region NOUN [face, -]
# region pobj of ADP [the, like]
# . punct verified VERB []
#
# Dependency Parsing Tree:
# Then face hypothesis are verified by searching for facial feature inside of the face-like region .
# ==================================================
# Constituency Parsing Tree:
# This nsubjpass done VERB []
# is auxpass done VERB []
# done ROOT done VERB [This, is, by, .]
# by prep done VERB [applying]
# applying pcomp by ADP [operation, intensity]
# morphological amod operation NOUN []
# operation dobj applying VERB [morphological, and, localization]
# and cc operation NOUN []
# minimum compound localization NOUN []
# localization conj operation NOUN [minimum]
# to aux intensity VERB []
# intensity advcl applying VERB [to, image]
# image dobj intensity VERB []
# . punct done VERB []
#
# Dependency Parsing Tree:
# This is done by applying morphological operation and minimum localization to intensity image .
# ==================================================
# Constituency Parsing Tree:
# There expl been AUX []
# have aux been AUX []
# been ROOT been AUX [There, have, advance, in, .]
# significant amod advance NOUN []
# advance attr been AUX [significant, in]
# in prep advance NOUN [Retrieval]
# Cross compound Retrieval PROPN []
# - compound Retrieval PROPN []
# Language compound Retrieval PROPN []
# Information compound Retrieval PROPN []
# Retrieval pobj in ADP [Cross, -, Language, Information, CLIR, )]
# ( punct CLIR PROPN []
# CLIR appos Retrieval PROPN [(]
# ) punct Retrieval PROPN []
# in prep been AUX [year]
# recent amod year NOUN []
# year pobj in ADP [recent]
# . punct been AUX []
#
# Dependency Parsing Tree:
# There have been significant advance in Cross-Language Information Retrieval ( CLIR ) in recent year .
# ==================================================
# Constituency Parsing Tree:
# One nsubj is AUX [of]
# of prep One NUM [reason]
# the det reason NOUN []
# major amod reason NOUN []
# remaining amod reason NOUN []
# reason pobj of ADP [the, major, remaining, perform]
# that mark perform VERB []
# CLIR nsubj perform VERB []
# doe aux perform VERB []
# not neg perform VERB []
# perform relcl reason NOUN [that, CLIR, doe, not, well]
# a det well NOUN []
# well dobj perform VERB [a]
# a det retrieval NOUN []
# monolingual amod retrieval NOUN []
# retrieval nsubj is AUX [a, monolingual]
# is ROOT is AUX [One, retrieval, presence, .]
# the det presence NOUN []
# presence attr is AUX [the, of, out]
# of prep presence NOUN []
# out prep presence NOUN [of, term]
# of prep out ADP [vocabulary]
# vocabulary pobj of ADP []
# ( punct term NOUN []
# OOV nmod term NOUN []
# ) punct term NOUN []
# term pobj out ADP [(, OOV, )]
# . punct is AUX []
#
# Dependency Parsing Tree:
# One of the major remaining reason that CLIR doe not perform a well a monolingual retrieval is the presence of out of vocabulary ( OOV ) term .
# ==================================================
# Constituency Parsing Tree:
# Previous amod work NOUN []
# work nsubj relied VERB [Previous]
# ha intj relied VERB []
# either preconj relied VERB []
# relied ROOT relied VERB [work, ha, either, on, or, been, .]
# on prep relied VERB [intervention]
# manual amod intervention NOUN []
# intervention pobj on ADP [manual]
# or cc relied VERB []
# ha nsubj been AUX []
# only advmod been AUX []
# been conj relied VERB [ha, only, successful]
# partially advmod successful ADJ []
# successful acomp been AUX [partially, in]
# in prep successful ADJ [solving]
# solving pcomp in ADP [problem]
# this det problem NOUN []
# problem dobj solving VERB [this]
# . punct relied VERB []
#
# Dependency Parsing Tree:
# Previous work ha either relied on manual intervention or ha only been partially successful in solving this problem .
# ==================================================
# Constituency Parsing Tree:
# We nsubj use VERB []
# use ROOT use VERB [We, method, ,, and, disambiguation, discover, .]
# a det method NOUN []
# method dobj use VERB [a, extends]
# that nsubj extends VERB []
# extends relcl method NOUN [that, work, in, by]
# earlier amod work NOUN []
# work dobj extends VERB [earlier]
# in prep extends VERB [area]
# this det area NOUN []
# area pobj in ADP [this]
# by prep extends VERB [augmenting]
# augmenting pcomp by ADP [this, with]
# this dobj augmenting VERB []
# with prep augmenting VERB [analysis]
# statistical amod analysis NOUN []
# analysis pobj with ADP [statistical]
# , punct use VERB []
# and cc use VERB []
# corpus npadvmod based VERB []
# - punct based VERB []
# based amod disambiguation NOUN [corpus, -]
# translation compound disambiguation NOUN []
# disambiguation dobj use VERB [based, translation]
# to aux discover VERB []
# dynamically advmod discover VERB []
# discover xcomp use VERB [to, dynamically, translation]
# translation dobj discover VERB [of]
# of prep translation NOUN [term]
# OOV compound term NOUN []
# term pobj of ADP [OOV]
# . punct use VERB []
#
# Dependency Parsing Tree:
# We use a method that extends earlier work in this area by augmenting this with statistical analysis , and corpus-based translation disambiguation to dynamically discover translation of OOV term .
# ==================================================
# Constituency Parsing Tree:
# The det method NOUN []
# method nsubjpass applied VERB [The]
# can aux applied VERB []
# be auxpass applied VERB []
# applied ROOT applied VERB [method, can, be, to, ,, extracting, .]
# to prep applied VERB [CLIR]
# both det CLIR PROPN []
# Chinese amod English PROPN []
# - punct English PROPN []
# English nmod CLIR PROPN [Chinese, -, and, English, Chinese]
# and cc English PROPN []
# English conj English PROPN []
# - punct Chinese ADJ []
# Chinese conj English PROPN [-]
# CLIR pobj to ADP [both, English]
# , punct applied VERB []
# correctly advmod extracting VERB []
# extracting advcl applied VERB [correctly, translation, automatically, ,, and, is]
# translation dobj extracting VERB [of, from]
# of prep translation NOUN [term]
# OOV compound term NOUN []
# term pobj of ADP [OOV]
# from prep translation NOUN [Web]
# the det Web NOUN []
# Web pobj from ADP [the]
# automatically advmod extracting VERB []
# , punct extracting VERB []
# and cc extracting VERB []
# thus advmod is AUX []
# is conj extracting VERB [thus, improvement]
# a det improvement NOUN []
# significant amod improvement NOUN []
# improvement attr is AUX [a, significant, on]
# on prep improvement NOUN [work]
# earlier amod work NOUN []
# work pobj on ADP [earlier]
# . punct applied VERB []
#
# Dependency Parsing Tree:
# The method can be applied to both Chinese-English and English-Chinese CLIR , correctly extracting translation of OOV term from the Web automatically , and thus is a significant improvement on earlier work .
# ==================================================
# Constituency Parsing Tree:
# Keywords nsubj play VERB []
# play ROOT play VERB [Keywords, role, .]
# an det role NOUN []
# important amod role NOUN []
# role dobj play VERB [an, important, in]
# in prep role NOUN [aspect]
# many amod aspect NOUN []
# aspect pobj in ADP [many, of]
# of prep aspect NOUN [retrieval]
# information compound retrieval NOUN []
# retrieval pobj of ADP [information, IR]
# ( punct IR PROPN []
# IR appos retrieval NOUN [(, )]
# ) punct IR PROPN []
# . punct play VERB []
#
# Dependency Parsing Tree:
# Keywords play an important role in many aspect of information retrieval ( IR ) .
# ==================================================
# Constituency Parsing Tree:
# From prep are AUX [search]
# Web compound search NOUN []
# search pobj From ADP [Web, to]
# to prep search NOUN [summarization]
# text compound summarization NOUN []
# summarization pobj to ADP [text]
# good amod keywords NOUN []
# keywords nsubj are AUX [good]
# are ROOT are AUX [From, keywords, necessity, .]
# a det necessity NOUN []
# necessity attr are AUX [a]
# . punct are AUX []
#
# Dependency Parsing Tree:
# From Web search to text summarization good keywords are a necessity .
# ==================================================
# Constituency Parsing Tree:
# In prep used VERB [system]
# a det system NOUN []
# typical amod system NOUN []
# IR compound system NOUN []
# system pobj In ADP [a, typical, IR]
# algorithm nsubjpass used VERB [require]
# are auxpass used VERB []
# used ROOT used VERB [In, algorithm, are, .]
# which nsubj require VERB []
# require relcl algorithm NOUN [which, collection]
# the det collection NOUN []
# entire amod collection NOUN []
# document compound collection NOUN []
# collection dobj require VERB [the, entire, document, built]
# to aux built VERB []
# be auxpass built VERB []
# built relcl collection NOUN [to, be, beforehand]
# beforehand advmod built VERB []
# . punct used VERB []
#
# Dependency Parsing Tree:
# In a typical IR system algorithm are used which require the entire document collection to be built beforehand .
# ==================================================
# Constituency Parsing Tree:
# While mark done VERB []
# some det research NOUN []
# research nsubjpass done VERB [some]
# ha intj done VERB []
# been auxpass done VERB []
# done ROOT done VERB [While, research, ha, been, on, ,, quality, .]
# on prep done VERB [extracting]
# extracting pcomp on ADP [keywords, from]
# keywords dobj extracting VERB []
# from prep extracting VERB [document]
# a det document NOUN []
# single amod document NOUN []
# document pobj from ADP [a, single]
# , punct done VERB []
# the det quality NOUN []
# quality conj done VERB [the, of, wa, based]
# of prep quality NOUN [keywords]
# the det keywords NOUN []
# keywords pobj of ADP [the]
# wa prep quality NOUN []
# not neg based VERB []
# based acl quality NOUN [not, on]
# on prep based VERB [perform]
# how advmod well ADV []
# well advmod perform VERB [how]
# they nsubj perform VERB []
# perform pcomp on ADP [well, they, in]
# in prep perform VERB [task]
# IR compound task NOUN []
# task pobj in ADP [IR]
# . punct done VERB []
#
# Dependency Parsing Tree:
# While some research ha been done on extracting keywords from a single document , the quality of the keywords wa not based on how well they perform in IR task .
# ==================================================
# Constituency Parsing Tree:
# Moreover advmod designed VERB []
# , punct designed VERB []
# they nsubjpass designed VERB []
# are auxpass designed VERB []
# designed ROOT designed VERB [Moreover, ,, they, are, for, is]
# for prep designed VERB [language]
# only advmod one NUM []
# one nummod language NOUN [only]
# language pobj for ADP [one, and]
# and cc language NOUN []
# the det applicability NOUN []
# applicability nsubj is AUX [the, to]
# to prep applicability NOUN [language]
# other amod language NOUN []
# language pobj to ADP [other]
# is conj designed VERB [applicability, unknown, .]
# unknown acomp is AUX []
# . punct is AUX []
#
# Dependency Parsing Tree:
# Moreover , they are designed for only one language and the applicability to other language is unknown .
# ==================================================
# Constituency Parsing Tree:
# As prep proposes VERB [such]
# such pobj As ADP []
# , punct proposes VERB []
# this det paper NOUN []
# paper nsubj proposes VERB [this]
# proposes ROOT proposes VERB [As, ,, paper, algorithm, .]
# a det algorithm PROPN []
# new amod algorithm PROPN []
# algorithm dobj proposes VERB [a, new, is]
# that nsubj is AUX []
# is relcl algorithm PROPN [that, applicable, and, extract]
# applicable acomp is AUX [to]
# to prep applicable ADJ [language]
# multiple amod language NOUN []
# language pobj to ADP [multiple]
# and cc is AUX []
# extract conj is AUX [keywords]
# effective amod keywords NOUN []
# keywords dobj extract VERB [effective, identify]
# that nsubj identify VERB []
# , punct identify VERB []
# to prep identify VERB [degree]
# a det degree NOUN []
# high amod degree NOUN []
# degree pobj to ADP [a, high]
# , punct identify VERB []
# uniquely advmod identify VERB []
# identify relcl keywords NOUN [that, ,, to, ,, uniquely, document]
# a det document NOUN []
# document dobj identify VERB [a]
# . punct proposes VERB []
#
# Dependency Parsing Tree:
# As such , this paper proposes a new algorithm that is applicable to multiple language and extract effective keywords that , to a high degree , uniquely identify a document .
# ==================================================
# Constituency Parsing Tree:
# It nsubj need VERB []
# need ROOT need VERB [It, document, and, rely, .]
# only advmod document NOUN []
# a det document NOUN []
# single amod document NOUN []
# document dobj need VERB [only, a, single, extract]
# to aux extract VERB []
# extract relcl document NOUN [to, keywords]
# keywords dobj extract VERB []
# and cc need VERB []
# doe aux rely VERB []
# not neg rely VERB []
# rely conj need VERB [doe, not, on]
# on prep rely VERB [method]
# machine compound learning NOUN []
# learning compound method NOUN [machine]
# method pobj on ADP [learning]
# . punct need VERB []
#
# Dependency Parsing Tree:
# It need only a single document to extract keywords and doe not rely on machine learning method .
# ==================================================
# Constituency Parsing Tree:
# It nsubj tested VERB []
# wa aux tested VERB []
# tested ROOT tested VERB [It, wa, on, .]
# on prep tested VERB [corpus]
# a det corpus NOUN []
# Japanese amod English PROPN []
# - punct English PROPN []
# English compound corpus NOUN [Japanese, -]
# bilingual amod corpus NOUN []
# corpus pobj on ADP [a, English, bilingual, and, portion]
# and cc corpus NOUN []
# a det portion NOUN []
# portion conj corpus NOUN [a, of, using]
# of prep portion NOUN [corpus]
# the det Reuter PROPN []
# Reuter poss corpus NOUN [the, 's]
# 's case Reuter PROPN []
# corpus pobj of ADP [Reuter]
# using acl portion NOUN [algorithm]
# a det algorithm PROPN []
# keyword compound search NOUN []
# search compound algorithm PROPN [keyword]
# algorithm dobj using VERB [a, search]
# . punct tested VERB []
#
# Dependency Parsing Tree:
# It wa tested on a Japanese-English bilingual corpus and a portion of the Reuter 's corpus using a keyword search algorithm .
# ==================================================
# Constituency Parsing Tree:
# The det result NOUN []
# result nsubj show VERB [The]
# show ROOT show VERB [result, do, .]
# that mark do VERB []
# the det keywords NOUN []
# extracted amod keywords NOUN []
# keywords nsubj do VERB [the, extracted]
# do ccomp show VERB [that, keywords, job, at]
# a det job NOUN []
# good amod job NOUN []
# job dobj do VERB [a, good]
# at prep do VERB [identifying]
# uniquely advmod identifying VERB []
# identifying pcomp at ADP [uniquely, document]
# the det document NOUN []
# document dobj identifying VERB [the]
# . punct show VERB []
#
# Dependency Parsing Tree:
# The result show that the extracted keywords do a good job at uniquely identifying the document .
# ==================================================
# Constituency Parsing Tree:
# This det article NOUN []
# article nsubj discus VERB [This]
# discus ROOT discus VERB [article, process, .]
# the det process NOUN []
# process dobj discus VERB [the, of]
# of prep process NOUN [extraction]
# enterprise compound knowledge NOUN []
# knowledge compound extraction NOUN [enterprise]
# extraction pobj of ADP [knowledge, from]
# from prep extraction NOUN [database]
# relational amod database NOUN []
# database pobj from ADP [relational, and, code]
# and cc database NOUN []
# source compound code NOUN []
# code conj database NOUN [source, of]
# of prep code NOUN [system]
# legacy amod system NOUN []
# information compound system NOUN []
# system pobj of ADP [legacy, information]
# . punct discus VERB []
#
# Dependency Parsing Tree:
# This article discus the process of enterprise knowledge extraction from relational database and source code of legacy information system .
# ==================================================
# Constituency Parsing Tree:
# Problems nsubjpass described VERB [of, solution]
# of prep Problems NOUN [system]
# legacy compound system NOUN []
# system pobj of ADP [legacy, and]
# and cc system NOUN []
# main amod solution NOUN []
# solution conj Problems NOUN [main, for]
# for prep solution NOUN [them]
# them pobj for ADP []
# are auxpass described VERB []
# briefly advmod described VERB []
# described ROOT described VERB [Problems, are, briefly, here, .]
# here advmod described VERB []
# . punct described VERB []
#
# Dependency Parsing Tree:
# Problems of legacy system and main solution for them are briefly described here .
# ==================================================
# Constituency Parsing Tree:
# The det us PROPN []
# us nsubj reverse VERB [The, of]
# of prep us PROPN [data]
# data pobj of ADP []
# reverse ROOT reverse VERB [us, technique, infer, analyzed]
# engineering nmod technique NOUN [and, understanding]
# and cc engineering NOUN []
# program compound understanding NOUN []
# understanding conj engineering NOUN [program]
# technique dobj reverse VERB [engineering]
# to aux infer VERB []
# automatically advmod infer VERB []
# infer advcl reverse VERB [to, automatically, much]
# a det much ADV []
# much dobj infer VERB [a]
# a det possible ADJ []
# possible amod schema NOUN [a]
# the det schema NOUN []
# schema nsubjpass analyzed VERB [possible, the, and, semantics, of]
# and cc schema NOUN []
# semantics conj schema NOUN []
# of prep schema NOUN [system]
# a det system NOUN []
# legacy amod system NOUN []
# information compound system NOUN []
# system pobj of ADP [a, legacy, information]
# is auxpass analyzed VERB []
# analyzed conj reverse VERB [schema, is, .]
# . punct analyzed VERB []
#
# Dependency Parsing Tree:
# The us of data reverse engineering and program understanding technique to automatically infer a much a possible the schema and semantics of a legacy information system is analyzed .
# ==================================================
# Constituency Parsing Tree:
# Eight nummod data NOUN []
# step compound data NOUN []
# data nsubj reverse VERB [Eight, step]
# reverse ROOT reverse VERB [data, algorithm, for, provided]
# engineering compound algorithm PROPN []
# algorithm dobj reverse VERB [engineering]
# for prep reverse VERB []
# knowledge compound extraction NOUN []
# extraction nsubjpass provided VERB [knowledge, from]
# from prep extraction NOUN [system]
# legacy compound system NOUN []
# system pobj from ADP [legacy]
# is auxpass provided VERB []
# provided advcl reverse VERB [extraction, is, .]
# . punct provided VERB []
#
# Dependency Parsing Tree:
# Eight step data reverse engineering algorithm for knowledge extraction from legacy system is provided .
# ==================================================
# Constituency Parsing Tree:
# A det example NOUN []
# hypothetical amod example NOUN []
# example nsubjpass presented VERB [A, hypothetical, of]
# of prep example NOUN [extraction]
# knowledge compound extraction NOUN []
# extraction pobj of ADP [knowledge, from]
# from prep extraction NOUN [system]
# legacy amod system NOUN []
# information compound system NOUN []
# system pobj from ADP [legacy, information]
# is auxpass presented VERB []
# presented ROOT presented VERB [example, is, .]
# . punct presented VERB []
#
# Dependency Parsing Tree:
# A hypothetical example of knowledge extraction from legacy information system is presented .
# ==================================================
# Constituency Parsing Tree:
# This det paper NOUN []
# paper nsubj is AUX [This]
# is ROOT is AUX [paper, concerned, .]
# mainly advmod concerned VERB []
# concerned acomp is AUX [mainly, with]
# with prep concerned VERB [process]
# low amod level NOUN []
# - punct level NOUN []
# level compound process NOUN [low, -]
# process pobj with ADP [level, in]
# in prep process NOUN [perception]
# machine compound perception NOUN []
# perception pobj in ADP [machine, of]
# of prep perception NOUN [motion]
# motion pobj of ADP []
# . punct is AUX []
#
# Dependency Parsing Tree:
# This paper is mainly concerned with low-level process in machine perception of motion .
# ==================================================
# Constituency Parsing Tree:
# A det system NOUN []
# motion compound analysis NOUN []
# analysis compound system NOUN [motion]
# system nsubj exploit VERB [A, analysis]
# should aux exploit VERB []
# exploit ROOT exploit VERB [system, should, information, '', during, .]
# information dobj exploit VERB [contained]
# contained acl information NOUN [in]
# in prep contained VERB [`, signal]
# ` punct in ADP []
# ` punct signal NOUN []
# early advmod warning NOUN []
# warning compound signal NOUN [early]
# signal pobj in ADP [`, warning]
# '' punct exploit VERB []
# during prep exploit VERB [phase]
# the det intensity NOUN []
# intensity npadvmod based VERB [the]
# based amod phase NOUN [intensity]
# peripheral amod phase NOUN []
# phase pobj during ADP [based, peripheral, of]
# of prep phase NOUN [perception]
# motion compound perception NOUN []
# perception pobj of ADP [motion]
# . punct exploit VERB []
#
# Dependency Parsing Tree:
# A motion analysis system should exploit information contained in `` early warning signal '' during the intensity based peripheral phase of motion perception .
# ==================================================
# Constituency Parsing Tree:
# We nsubj show VERB []
# show ROOT show VERB [We, contain, .]
# that mark contain VERB []
# intensity npadvmod based VERB []
# based amod picture NOUN [intensity]
# difference compound picture NOUN []
# picture nsubj contain VERB [based, difference]
# contain ccomp show VERB [that, picture, information, ,, and, method]
# motion compound information NOUN []
# information dobj contain VERB [motion, about]
# about prep information NOUN [object]
# object pobj about ADP [in]
# in prep object NOUN [scene]
# a det scene NOUN []
# dynamic amod scene NOUN []
# scene pobj in ADP [a, dynamic]
# , punct contain VERB []
# and cc contain VERB []
# present amod method NOUN []
# method conj contain VERB [present, for]
# for prep method NOUN [extraction]
# the det extraction NOUN []
# extraction pobj for ADP [the, of, in]
# of prep extraction NOUN [information]
# motion compound information NOUN []
# information pobj of ADP [motion]
# in prep extraction NOUN [phase]
# the det phase NOUN []
# peripheral amod phase NOUN []
# phase pobj in ADP [the, peripheral]
# . punct show VERB []
#
# Dependency Parsing Tree:
# We show that intensity based difference picture contain motion information about object in a dynamic scene , and present method for the extraction of motion information in the peripheral phase .
# ==================================================
# Constituency Parsing Tree:
# Some det experiment NOUN []
# experiment nsubj demonstrate VERB [Some, with, generated, scene]
# with prep experiment NOUN [laboratory]
# laboratory pobj with ADP []
# generated acl experiment NOUN [and]
# and cc generated VERB []
# real amod scene NOUN []
# world compound scene NOUN []
# scene conj experiment NOUN [real, world]
# demonstrate ROOT demonstrate VERB [experiment, potential, .]
# the det potential NOUN []
# potential dobj demonstrate VERB [the, of]
# of prep potential NOUN [technique]
# the det technique NOUN []
# technique pobj of ADP [the]
# ...
# extraction pobj including VERB [information, ,, learning]
# , punct extraction NOUN []
# representation compound learning NOUN []
# learning conj extraction NOUN [representation, ,, prediction]
# , punct learning NOUN []
# outcome compound prediction NOUN []
# prediction conj learning NOUN [outcome, ,, phenotyping]
# , punct prediction NOUN []
# phenotyping conj prediction NOUN [,, and, deidentification]
# , punct phenotyping NOUN []
# and cc phenotyping NOUN []
# deidentification conj phenotyping NOUN []
# . punct survey VERB []
#
# Dependency Parsing Tree:
# In this review , we survey the current research on applying deep learning to clinical task based on EHR data , where we find a variety of deep learning technique and framework being applied to several type of clinical application including information extraction , representation learning , outcome prediction , phenotyping , and deidentification .
# ==================================================
# Constituency Parsing Tree:
# We nsubj identify VERB []
# identify ROOT identify VERB [We, limitation, .]
# several amod limitation NOUN []
# limitation dobj identify VERB [several, of, interpretability]
# of prep limitation NOUN [research]
# current amod research NOUN []
# research pobj of ADP [current, involving]
# involving acl research NOUN [topic]
# topic dobj involving VERB []
# such predet interpretability NOUN []
# a det interpretability NOUN []
# model compound interpretability NOUN []
# interpretability conj limitation NOUN [such, a, model, ,, heterogeneity]
# , punct interpretability NOUN []
# data compound heterogeneity NOUN []
# heterogeneity conj interpretability NOUN [data, ,, and, lack]
# , punct heterogeneity NOUN []
# and cc heterogeneity NOUN []
# lack conj heterogeneity NOUN [of]
# of prep lack NOUN [benchmark]
# universal amod benchmark NOUN []
# benchmark pobj of ADP [universal]
# . punct identify VERB []
#
# Dependency Parsing Tree:
# We identify several limitation of current research involving topic such a model interpretability , data heterogeneity , and lack of universal benchmark .
# ==================================================
# Constituency Parsing Tree:
# We nsubj conclude VERB []
# conclude ROOT conclude VERB [We, by, .]
# by prep conclude VERB [summarizing]
# summarizing pcomp by ADP [state, and, identifying]
# the det state NOUN []
# state dobj summarizing VERB [the, of]
# of prep state NOUN [field]
# the det field NOUN []
# field pobj of ADP [the]
# and cc summarizing VERB []
# identifying conj summarizing VERB [avenue]
# avenue dobj identifying VERB [of]
# of prep avenue NOUN [research]
# future amod research NOUN []
# deep amod research NOUN []
# EHR compound research NOUN []
# research pobj of ADP [future, deep, EHR]
# . punct conclude VERB []
#
# Dependency Parsing Tree:
# We conclude by summarizing the state of the field and identifying avenue of future deep EHR research .
# ==================================================
# Constituency Parsing Tree:
# We nsubj completed VERB []
# have aux completed VERB []
# recently advmod completed VERB []
# completed ROOT completed VERB [We, have, recently, sixth, in, .]
# the det sixth ADJ []
# sixth dobj completed VERB [the]
# in prep completed VERB [series]
# a det series NOUN []
# series pobj in ADP [a, of]
# of prep series NOUN [`, Conferences]
# ` punct of ADP []
# ` punct Conferences PROPN []
# Message compound Conferences PROPN []
# Understanding compound Conferences PROPN []
# Conferences pobj of ADP [`, Message, Understanding, '', designed]
# '' punct Conferences PROPN []
# which nsubjpass designed VERB []
# are auxpass designed VERB []
# designed relcl Conferences PROPN [which, are, promote]
# to aux promote VERB []
# promote xcomp designed VERB [to, and, evaluate]
# and cc promote VERB []
# evaluate conj promote VERB [research]
# research dobj evaluate VERB [in]
# in prep research NOUN [extraction]
# information compound extraction NOUN []
# extraction pobj in ADP [information]
# . punct completed VERB []
#
# Dependency Parsing Tree:
# We have recently completed the sixth in a series of `` Message Understanding Conferences '' which are designed to promote and evaluate research in information extraction .
# ==================================================
# Constituency Parsing Tree:
# MUC-6 nsubj introduced VERB []
# introduced ROOT introduced VERB [MUC-6, innovation, ,, in, .]
# several amod innovation NOUN []
# innovation dobj introduced VERB [several, over]
# over prep innovation NOUN [MUCs]
# prior amod MUCs NOUN []
# MUCs pobj over ADP [prior]
# , punct introduced VERB []
# most advmod notably ADV []
# notably advmod in ADP [most]
# in prep introduced VERB [notably, range]
# the det range NOUN []
# range pobj in ADP [the, of]
# of prep range NOUN [task]
# different amod task NOUN []
# task pobj of ADP [different, conducted]
# for mark conducted VERB []
# which det evaluation NOUN []
# evaluation nsubjpass conducted VERB [which]
# were auxpass conducted VERB []
# conducted relcl task NOUN [for, evaluation, were]
# . punct introduced VERB []
#
# Dependency Parsing Tree:
# MUC-6 introduced several innovation over prior MUCs , most notably in the range of different task for which evaluation were conducted .
# ==================================================
# Constituency Parsing Tree:
# We nsubj describe VERB []
# describe ROOT describe VERB [We, some, and, discus, .]
# some dobj describe VERB [of]
# of prep some PRON [motivation]
# the det motivation NOUN []
# motivation pobj of ADP [the, for]
# for prep motivation NOUN [format]
# the det format NOUN []
# new amod format NOUN []
# format pobj for ADP [the, new]
# and cc describe VERB []
# briefly advmod discus VERB []
# discus conj describe VERB [briefly, some]
# some dobj discus VERB [of]
# of prep some PRON [result]
# the det result NOUN []
# result pobj of ADP [the, of]
# of prep result NOUN [evaluation]
# the det evaluation NOUN []
# evaluation pobj of ADP [the]
# . punct describe VERB []
#
# Dependency Parsing Tree:
# We describe some of the motivation for the new format and briefly discus some of the result of the evaluation .
# ==================================================
# Constituency Parsing Tree:
# Face nsubj is AUX []
# is ROOT is AUX [Face, model, and, is]
# a det model NOUN []
# complex amod model NOUN []
# multidimensional amod model NOUN []
# visual amod model NOUN []
# model attr is AUX [a, complex, multidimensional, visual]
# and cc is AUX []
# developing csubj is AUX [model]
# a det model NOUN []
# computational amod model NOUN []
# model dobj developing VERB [a, computational, for]
# for prep model NOUN [recognition]
# face compound recognition NOUN []
# recognition pobj for ADP [face]
# is conj is AUX [developing, difficult, .]
# difficult acomp is AUX []
# . punct is AUX []
#
# Dependency Parsing Tree:
# Face is a complex multidimensional visual model and developing a computational model for face recognition is difficult .
# ==================================================
# Constituency Parsing Tree:
# The det paper NOUN []
# paper nsubj present VERB [The]
# present ROOT present VERB [paper, methodology, based, .]
# a det methodology NOUN []
# methodology dobj present VERB [a, for]
# for prep methodology NOUN [recognition]
# face compound recognition NOUN []
# recognition pobj for ADP [face]
# based prep present VERB [on]
# on prep based VERB [approach]
# information compound theory NOUN []
# theory compound approach NOUN [information]
# approach pobj on ADP [theory, of]
# of prep approach NOUN [coding]
# coding pcomp of ADP [and, decoding]
# and cc coding VERB []
# decoding conj coding VERB [image]
# the det image NOUN []
# face compound image NOUN []
# image dobj decoding VERB [the, face]
# . punct present VERB []
#
# Dependency Parsing Tree:
# The paper present a methodology for face recognition based on information theory approach of coding and decoding the face image .
# ==================================================
# Constituency Parsing Tree:
# Proposed amod methodology NOUN []
# methodology nsubj is AUX [Proposed]
# is ROOT is AUX [methodology, connection, .]
# connection attr is AUX [of]
# of prep connection NOUN [extraction]
# two nummod extraction NOUN []
# stage compound Feature NOUN []
# - punct Feature NOUN []
# Feature compound extraction NOUN [stage, -]
# extraction pobj of ADP [two, Feature, using, using]
# using acl extraction NOUN [Analysis]
# Principle compound Analysis PROPN []
# Component compound Analysis PROPN []
# Analysis dobj using VERB [Principle, Component, and, recognition]
# and cc Analysis PROPN []
# recognition conj Analysis PROPN []
# using acl extraction NOUN [feed, forward, Network]
# the det feed NOUN []
# feed dobj using VERB [the]
# forward advmod using VERB []
# back amod propagation NOUN []
# propagation compound Network PROPN [back]
# Neural compound Network PROPN []
# Network dobj using VERB [propagation, Neural]
# . punct is AUX []
#
# Dependency Parsing Tree:
# Proposed methodology is connection of two stage - Feature extraction using Principle Component Analysis and recognition using the feed forward back propagation Neural Network .
# ==================================================
# Constituency Parsing Tree:
# The det goal NOUN []
# goal nsubj is AUX [The]
# is ROOT is AUX [goal, implement, .]
# to aux implement VERB []
# implement xcomp is AUX [to, system, for, and, distinguish]
# the det system NOUN []
# system dobj implement VERB [the, (, model, )]
# ( punct system NOUN []
# model appos system NOUN []
# ) punct system NOUN []
# for prep implement VERB [face]
# a det face NOUN []
# particular amod face NOUN []
# face pobj for ADP [a, particular]
# and cc implement VERB []
# distinguish conj implement VERB [it, from, well]
# it dobj distinguish VERB []
# from prep distinguish VERB [number]
# a det number NOUN []
# large amod number NOUN []
# number pobj from ADP [a, large, of, with]
# of prep number NOUN [face]
# stored amod face NOUN []
# face pobj of ADP [stored]
# with prep number NOUN [variation]
# some det variation NOUN []
# real amod time NOUN []
# - punct time NOUN []
# time compound variation NOUN [real, -]
# variation pobj with ADP [some, time]
# a det well NOUN []
# well advmod distinguish VERB [a]
# . punct is AUX []
#
# Dependency Parsing Tree:
# The goal is to implement the system ( model ) for a particular face and distinguish it from a large number of stored face with some real-time variation a well .
# ==================================================
# Constituency Parsing Tree:
# The det Eigenface PROPN []
# Eigenface nsubj approach VERB [The]
# approach ROOT approach VERB [Eigenface, us, Analysis]
# us dative approach VERB []
# Principal compound Analysis PROPN []
# Component compound Analysis PROPN []
# Analysis dobj approach VERB [Principal, Component, PCA]
# ( punct PCA PROPN []
# PCA appos Analysis PROPN [(, )]
# ) punct PCA PROPN []
# algorithm ROOT algorithm PROPN [for, .]
# for prep algorithm PROPN [recognition]
# the det recognition NOUN []
# recognition pobj for ADP [the, of]
# of prep recognition NOUN [image]
# the det image NOUN []
# image pobj of ADP [the]
# . punct algorithm PROPN []
#
# Dependency Parsing Tree:
# The Eigenface approach us Principal Component Analysis ( PCA ) algorithm for the recognition of the image .
# ==================================================
# Constituency Parsing Tree:
# It nsubj give VERB []
# give ROOT give VERB [It, u, way, .]
# u dative give VERB []
# efficient amod way NOUN []
# way dobj give VERB [efficient, find]
# to aux find VERB []
# find relcl way NOUN [to, space]
# the det space NOUN []
# lower amod space NOUN []
# dimensional amod space NOUN []
# space dobj find VERB [the, lower, dimensional]
# . punct give VERB []
#
# Dependency Parsing Tree:
# It give u efficient way to find the lower dimensional space .
# ==================================================
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                   NaN
# ...                                                 ...
# 9995  The image displayed in computed tomography is ...
# 9996  Automatically acquiring synonymous collocation...
# 9997  The past decade has seen an explosion in the a...
# 9998  We have recently completed the sixth in a seri...
# 9999  Face is a complex multidimensional visual mode...
#
#                                        cleaned_abstract  \
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4                                                   NaN
# ...                                                 ...
# 9995  the image displayed in computed tomography is ...
# 9996  automatically acquiring synonymous collocation...
# 9997  the past decade has seen an explosion in the a...
# 9998  we have recently completed the sixth in a seri...
# 9999  face is a complex multidimensional visual mode...
#
#                              abstract_without_stopwords  \
# 0     present Fashion-MNIST, new dataset comprising ...
# 1     TensorFlow machine learning system operates la...
# 2     TensorFlow interface expressing machine learni...
# 3     goal precipitation nowcasting predict future r...
# 4                                                   NaN
# ...                                                 ...
# 9995  image displayed computed tomography scaled rep...
# 9996  Automatically acquiring synonymous collocation...
# 9997  past decade seen explosion amount digital info...
# 9998  recently completed sixth series "Message Under...
# 9999  Face complex multidimensional visual model dev...
#
#                                        stemmed_abstract  \
# 0     we present fashion-mnist , a new dataset compr...
# 1     tensorflow is a machin learn system that oper ...
# 2     tensorflow is an interfac for express machin l...
# 3     the goal of precipit nowcast is to predict the...
# 4                                                   NaN
# ...                                                 ...
# 9995  the imag display in comput tomographi is a sca...
# 9996  automat acquir synonym colloc pair such as and...
# 9997  the past decad ha seen an explos in the amount...
# 9998  we have recent complet the sixth in a seri of ...
# 9999  face is a complex multidimension visual model ...
#
#                                     lemmatized_abstract  noun  verb  adjective  adverb  \
# 0     We present Fashion-MNIST , a new dataset compr...    32     9          8       1
# 1     TensorFlow is a machine learning system that o...    63    25         17       2
# 2     TensorFlow is an interface for expressing mach...    64    28         19       1
# 3     The goal of precipitation nowcasting is to pre...    43    18         16       5
# 4                                                   NaN     0     0          0       0
# ...                                                 ...   ...   ...        ...     ...
# 9995  The image displayed in computed tomography is ...    34    15         15       1
# 9996  Automatically acquiring synonymous collocation...    48    25         29      10
# 9997  The past decade ha seen an explosion in the am...    59    20         23       1
# 9998  We have recently completed the sixth in a seri...    18    11          6       2
# 9999  Face is a complex multidimensional visual mode...    46    15         14       2
#
#                                                entities
# 0     [28x28 - CARDINAL, 70,000 - CARDINAL, 10 - CAR...
# 1     [TensorFlow - ORG, ASICs - ORG, Tensor Process...
# 2     [TensorFlow - PRODUCT, TensorFlow - PRODUCT, h...
# 3                          [FC-LSTM - ORG, ROVER - ORG]
# 4                                                    []
# ...                                                 ...
# 9995                    [CT - ORG, Rutherford - PERSON]
# 9996  [first - ORDINAL, second - ORDINAL, 74 % and 6...
# 9997                           [The past decade - DATE]
# 9998  [sixth - ORDINAL, Message Understanding Confer...
# 9999  [two - CARDINAL, Principle Component Analysis ...
#
# [10000 rows x 10 columns]

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below

I find it ch
