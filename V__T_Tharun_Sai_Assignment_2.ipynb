# %% [markdown]
# <a href="https://colab.research.google.com/github/TharunSaiVT/INFO-5731/blob/main/V__T_Tharun_Sai_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
# !pip install semanticscholar
# Out:
# Collecting semanticscholar
#   Downloading semanticscholar-0.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from semanticscholar) (8.2.3)
# Collecting httpx (from semanticscholar)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from semanticscholar) (1.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (2024.2.2)
# Collecting httpcore==1.* (from httpx->semanticscholar)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->semanticscholar) (1.3.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->semanticscholar)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->semanticscholar) (1.2.0)
# Installing collected packages: h11, httpcore, httpx, semanticscholar
# Successfully installed h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 semanticscholar-0.7.0

# %%
import pandas as pd
import warnings
import time
from semanticscholar import SemanticScholar

# Ignoring warnings
warnings.filterwarnings("ignore")
pd.set_option('display.width', None)

# Initialization
sem_sch = SemanticScholar()

# Function to fetch abstracts iteratively
def fetch_abstracts(keywords, count):
    total_abstracts = []
    offset = 0
    while count > 0:
        for keyword in keywords:
            start_time = time.time()
            res = sem_sch.search_paper([keyword], fields=['abstract'])
            for paper in res:
                total_abstracts.append({'abstract': paper.abstract})
                count -= 1
                if count == 0:
                    break
                # Check if time limit (10 seconds) is exceeded
                if time.time() - start_time > 10:
                    break
            if count == 0:
                break
        offset += 1
    return total_abstracts

# Search articles using multiple topics and fetch 10000 abstracts
abstracts = fetch_abstracts(['machine learning', 'data science', 'artificial intelligence', 'information extraction'], 10000)

# Create DataFrame
df_paper = pd.DataFrame(abstracts)

# Save to CSV
df_paper.to_csv('output.csv', index=False)

# Print DataFrame
print(df_paper)
# Out:
#                                                abstract
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations of Comput...
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999  Updated and expanded, Bayesian Artificial Inte...
#
# [10000 rows x 1 columns]

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import pandas as pd
import re
import warnings
from semanticscholar import SemanticScholar


# Function to clean text by removing special characters and punctuations
def clean_text(text):
    if text is None:
        return ''
    # Remove special characters and punctuations using regular expressions
    cleaned_text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    return cleaned_text

# Clean the abstracts and save the clean data in a new column
df_paper['cleaned_abstract'] = df_paper['abstract'].apply(clean_text)

# Save DataFrame to CSV with both original and cleaned abstracts
df_paper.to_csv('output_with_cleaned_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations of Comput...
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999  Updated and expanded, Bayesian Artificial Inte...
#
#                                        cleaned_abstract
# 0     We present FashionMNIST a new dataset comprisi...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  Artificial Intelligence Foundations of Computa...
# 9996
# 9997
# 9998
# 9999  Updated and expanded Bayesian Artificial Intel...
#
# [10000 rows x 2 columns]

# %%
import pandas as pd
import re
import warnings
from semanticscholar import SemanticScholar


# Function to clean text by removing numbers
def clean_text(text):
    if text is None:
        return ''
    # Remove numbers using regular expressions
    cleaned_text = ''.join([i for i in text if not i.isdigit()])
    return cleaned_text

# Clean the abstracts and save the clean data in a new column
df_paper['cleaned_abstract'] = df_paper['abstract'].apply(clean_text)

# Save DataFrame to CSV with both original and cleaned abstracts
df_paper.to_csv('output_with_cleaned_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations of Comput...
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999  Updated and expanded, Bayesian Artificial Inte...
#
#                                        cleaned_abstract
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations of Comput...
# 9996
# 9997
# 9998
# 9999  Updated and expanded, Bayesian Artificial Inte...
#
# [10000 rows x 2 columns]

# %%
import pandas as pd
import re
import warnings
from semanticscholar import SemanticScholar


# Function to lower the text
def clean_text(text):
    if text is None:
        return ''
    # functions to lowercase all the letters
    cleaned_text = text.lower()
    return cleaned_text

# Clean the abstracts and save the clean data in a new column
df_paper['cleaned_abstract'] = df_paper['abstract'].apply(clean_text)

# Save DataFrame to CSV with both original and cleaned abstracts
df_paper.to_csv('output_with_cleaned_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations of Comput...
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999  Updated and expanded, Bayesian Artificial Inte...
#
#                                        cleaned_abstract
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  artificial intelligence: foundations of comput...
# 9996
# 9997
# 9998
# 9999  updated and expanded, bayesian artificial inte...
#
# [10000 rows x 2 columns]

# %%
import pandas as pd
import re
import warnings
import nltk
from semanticscholar import SemanticScholar
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

# Function to clean text by removing stopwords
def remove_stopwords(text):
    if text is None:
        return ''
    # Tokenize the text
    words = text.split()
    # Remove stopwords
    filtered_words = [word for word in words if word.lower() not in stop_words]
    # Join the filtered words back into a string
    cleaned_text = ' '.join(filtered_words)
    return cleaned_text

# Clean the abstracts by removing stopwords and save the clean data in a new column
df_paper['abstract_without_stopwords'] = df_paper['abstract'].apply(remove_stopwords)

# Save DataFrame to CSV with both original and cleaned abstracts
df_paper.to_csv('output_without_stopwords.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations of Comput...
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999  Updated and expanded, Bayesian Artificial Inte...
#
#                                        cleaned_abstract  \
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  artificial intelligence: foundations of comput...
# 9996
# 9997
# 9998
# 9999  updated and expanded, bayesian artificial inte...
#
#                              abstract_without_stopwords
# 0     present Fashion-MNIST, new dataset comprising ...
# 1     TensorFlow machine learning system operates la...
# 2     TensorFlow interface expressing machine learni...
# 3     goal precipitation nowcasting predict future r...
# 4
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations Computati...
# 9996
# 9997
# 9998
# 9999  Updated expanded, Bayesian Artificial Intellig...
#
# [10000 rows x 3 columns]

# %%
import pandas as pd
import re
import warnings
import nltk
from semanticscholar import SemanticScholar
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Create a stemmer object
porter_stemmer = PorterStemmer()

# Function to perform stemming on text
def perform_stemming(text):
    if text is None:
        return ''
    # Tokenize the text
    words = word_tokenize(text)
    # Perform stemming on each word
    stemmed_words = [porter_stemmer.stem(word) for word in words]
    # Join the stemmed words back into a string
    stemmed_text = ' '.join(stemmed_words)
    return stemmed_text

# Perform stemming on the abstracts and save the clean data in a new column
df_paper['stemmed_abstract'] = df_paper['abstract'].apply(perform_stemming)

# Save DataFrame to CSV with both original and stemmed abstracts
df_paper.to_csv('output_with_stemmed_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
df_paper
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations of Comput...
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999  Updated and expanded, Bayesian Artificial Inte...
#
#                                        cleaned_abstract  \
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  artificial intelligence: foundations of comput...
# 9996
# 9997
# 9998
# 9999  updated and expanded, bayesian artificial inte...
#
#                              abstract_without_stopwords  \
# 0     present Fashion-MNIST, new dataset comprising ...
# 1     TensorFlow machine learning system operates la...
# 2     TensorFlow interface expressing machine learni...
# 3     goal precipitation nowcasting predict future r...
# 4
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations Computati...
# 9996
# 9997
# 9998
# 9999  Updated expanded, Bayesian Artificial Intellig...
#
#                                        stemmed_abstract
# 0     we present fashion-mnist , a new dataset compr...
# 1     tensorflow is a machin learn system that oper ...
# 2     tensorflow is an interfac for express machin l...
# 3     the goal of precipit nowcast is to predict the...
# 4
# ...                                                 ...
# 9995  artifici intellig : foundat of comput agent is...
# 9996
# 9997
# 9998
# 9999  updat and expand , bayesian artifici intellig ...
#
# [10000 rows x 4 columns]

# %%
import pandas as pd
import re
import warnings
import nltk
from semanticscholar import SemanticScholar
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
# Create a lemmatizer object
lemmatizer = WordNetLemmatizer()

# Function to perform lemmatization on text
def perform_lemmatization(text):
    if text is None:
        return ''
    # Tokenize the text
    words = word_tokenize(text)
    # Perform lemmatization on each word
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    # Join the lemmatized words back into a string
    lemmatized_text = ' '.join(lemmatized_words)
    return lemmatized_text

# Perform lemmatization on the abstracts and save the clean data in a new column
df_paper['lemmatized_abstract'] = df_paper['abstract'].apply(perform_lemmatization)

# Save DataFrame to CSV with both original and lemmatized abstracts
df_paper.to_csv('output_with_lemmatized_abstract.csv', index=False)

# Optionally, you can also return or further manipulate the DataFrame
print(df_paper)
print('\n')

# Select only the fifth column ('lemmatized_abstract')
fifth_column = df_paper['lemmatized_abstract']

# Save the fifth column to a new CSV file
fifth_column.to_csv('fifth_column.csv', index=False, header=['lemmatized_abstract'])

print("The Column of Lemmatized Abstract \n",fifth_column)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                                abstract  \
# 0     We present Fashion-MNIST, a new dataset compri...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4                                                  None
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations of Comput...
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999  Updated and expanded, Bayesian Artificial Inte...
#
#                                        cleaned_abstract  \
# 0     we present fashion-mnist, a new dataset compri...
# 1     tensorflow is a machine learning system that o...
# 2     tensorflow is an interface for expressing mach...
# 3     the goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  artificial intelligence: foundations of comput...
# 9996
# 9997
# 9998
# 9999  updated and expanded, bayesian artificial inte...
#
#                              abstract_without_stopwords  \
# 0     present Fashion-MNIST, new dataset comprising ...
# 1     TensorFlow machine learning system operates la...
# 2     TensorFlow interface expressing machine learni...
# 3     goal precipitation nowcasting predict future r...
# 4
# ...                                                 ...
# 9995  Artificial Intelligence: Foundations Computati...
# 9996
# 9997
# 9998
# 9999  Updated expanded, Bayesian Artificial Intellig...
#
#                                        stemmed_abstract  \
# 0     we present fashion-mnist , a new dataset compr...
# 1     tensorflow is a machin learn system that oper ...
# 2     tensorflow is an interfac for express machin l...
# 3     the goal of precipit nowcast is to predict the...
# 4
# ...                                                 ...
# 9995  artifici intellig : foundat of comput agent is...
# 9996
# 9997
# 9998
# 9999  updat and expand , bayesian artifici intellig ...
#
#                                     lemmatized_abstract
# 0     We present Fashion-MNIST , a new dataset compr...
# 1     TensorFlow is a machine learning system that o...
# 2     TensorFlow is an interface for expressing mach...
# 3     The goal of precipitation nowcasting is to pre...
# 4
# ...                                                 ...
# 9995  Artificial Intelligence : Foundations of Compu...
# 9996
# 9997
# 9998
# 9999  Updated and expanded , Bayesian Artificial Int...
#
# [10000 rows x 5 columns]
#
#
# The Column of Lemmatized Abstract
#  0       We present Fashion-MNIST , a new dataset compr...
# 1       TensorFlow is a machine learning system that o...
# 2       TensorFlow is an interface for expressing mach...
# 3       The goal of precipitation nowcasting is to pre...
# 4
#                               ...
# 9995    Artificial Intelligence : Foundations of Compu...
# 9996
# 9997
# 9998
# 9999    Updated and expanded , Bayesian Artificial Int...
# Name: lemmatized_abstract, Length: 10000, dtype: object

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag
import spacy
nltk.download('averaged_perceptron_tagger')

# Load SpaCy English model for Named Entity Recognition
nlp = spacy.load("en_core_web_sm")

# Read the CSV file containing the clean text
try:
    df = pd.read_csv('fifth_column.csv')
except FileNotFoundError:
    print("File not found. Please ensure the file path is correct.")
    exit()
except Exception as e:
    print("An error occurred while reading the CSV file:", e)
    exit()

# Function to conduct Parts of Speech (POS) Tagging and calculate counts
def pos_tagging_and_count(text):
    nouns = verbs = adjectives = adverbs = 0
    if isinstance(text, str):  # Check if text is a string
        tokens = word_tokenize(text)
        pos_tags = pos_tag(tokens)
        for _, tag in pos_tags:
            if tag.startswith('N'):  # Noun
                nouns += 1
            elif tag.startswith('V'):  # Verb
                verbs += 1
            elif tag.startswith('J'):  # Adjective
                adjectives += 1
            elif tag.startswith('R'):  # Adverb
                adverbs += 1
    return nouns, verbs, adjectives, adverbs

# Function to perform Constituency Parsing and Dependency Parsing
def parse_trees(text):
    if isinstance(text, str):  # Check if text is a string
        sentences = sent_tokenize(text)
        for sentence in sentences:
            print("Constituency Parsing Tree:")
            parsed_sentence = nlp(sentence)
            for token in parsed_sentence:
                print(token.text, token.dep_, token.head.text, token.head.pos_,
                      [child for child in token.children])
            print("\nDependency Parsing Tree:")
            print(parsed_sentence)
            print("="*50)

# Function to perform Named Entity Recognition (NER) and calculate counts
def ner_and_count(text):
    entities = []
    if isinstance(text, str):  # Check if text is a string
        doc = nlp(text)
        for ent in doc.ents:
            entities.append(ent.text + " - " + ent.label_)
    return entities

# Apply functions to each row of the DataFrame
df['noun'], df['verb'], df['adjective'], df['adverb'] = zip(*df['lemmatized_abstract'].apply(pos_tagging_and_count))
df['lemmatized_abstract'].head(2).apply(parse_trees)  #runs only 2 abstracts or 2 lines of the abstract to avoid more execution time.
df['entities'] = df['lemmatized_abstract'].apply(ner_and_count)

# Display DataFrame with added columns
print(df)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Constituency Parsing Tree:
# We nsubj present VERB []
# present ROOT present VERB [We, MNIST, ,, with, .]
# Fashion compound MNIST PROPN []
# - punct MNIST PROPN []
# MNIST dobj present VERB [Fashion, -, ,, comprising]
# , punct MNIST PROPN []
# a det comprising NOUN []
# new amod comprising NOUN []
# dataset amod comprising NOUN []
# comprising appos MNIST PROPN [a, new, dataset, of, from]
# of prep comprising NOUN [image]
# 28x28 nummod image NOUN []
# grayscale compound image NOUN []
# image pobj of ADP [28x28, grayscale, of]
# of prep image NOUN [product]
# 70,000 nummod product NOUN []
# fashion compound product NOUN []
# product pobj of ADP [70,000, fashion]
# from prep comprising NOUN [category]
# 10 nummod category NOUN []
# category pobj from ADP [10]
# , punct present VERB []
# with prep present VERB [image]
# 7,000 nummod image NOUN []
# image pobj with ADP [7,000, per]
# per prep image NOUN [category]
# category pobj per ADP []
# . punct present VERB []
#
# Dependency Parsing Tree:
# We present Fashion-MNIST , a new dataset comprising of 28x28 grayscale image of 70,000 fashion product from 10 category , with 7,000 image per category .
# ==================================================
# Constituency Parsing Tree:
# The det training NOUN []
# training nsubj set VERB [The]
# set ROOT set VERB [training, ha, image, ha, image, .]
# ha intj set VERB []
# 60,000 nummod image NOUN []
# image dobj set VERB [60,000, and, test]
# and cc image NOUN []
# the det test NOUN []
# test conj image NOUN [the, set]
# set acl test NOUN []
# ha prep set VERB []
# 10,000 nummod image NOUN []
# image dobj set VERB [10,000]
# . punct set VERB []
#
# Dependency Parsing Tree:
# The training set ha 60,000 image and the test set ha 10,000 image .
# ==================================================
# Constituency Parsing Tree:
# Fashion compound MNIST PROPN []
# - punct MNIST PROPN []
# MNIST nsubjpass intended VERB [Fashion, -]
# is auxpass intended VERB []
# intended ccomp share VERB [MNIST, is, serve, ,]
# to aux serve VERB []
# serve xcomp intended VERB [to, replacement]
# a det replacement NOUN []
# a det replacement NOUN []
# direct amod replacement NOUN []
# drop nmod replacement NOUN [-, in]
# - punct drop NOUN []
# in prt drop NOUN []
# replacement dobj serve VERB [a, a, direct, drop, for]
# for prep replacement NOUN [dataset]
# the det dataset NOUN []
# original amod dataset NOUN []
# MNIST compound dataset NOUN []
# dataset pobj for ADP [the, original, MNIST, for]
# for prep dataset NOUN [benchmarking]
# benchmarking pcomp for ADP [algorithm]
# machine compound learning NOUN []
# learning compound algorithm PROPN [machine]
# algorithm dobj benchmarking VERB [learning]
# , punct intended VERB []
# a det share VERB []
# it nsubj share VERB []
# share ROOT share VERB [intended, a, it, size, .]
# the det size NOUN []
# same amod size NOUN []
# image compound size NOUN []
# size dobj share VERB [the, same, image, ,, format]
# , punct size NOUN []
# data compound format NOUN []
# format conj size NOUN [data, and, structure]
# and cc format NOUN []
# the det structure NOUN []
# structure conj format NOUN [the, of]
# of prep structure NOUN [split]
# training nmod split NOUN [and, testing]
# and cc training NOUN []
# testing conj training NOUN []
# split pobj of ADP [training]
# . punct share VERB []
#
# Dependency Parsing Tree:
# Fashion-MNIST is intended to serve a a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithm , a it share the same image size , data format and the structure of training and testing split .
# ==================================================
# Constituency Parsing Tree:
# The det dataset NOUN []
# dataset nsubj is AUX [The]
# is ROOT is AUX [dataset, available, at]
# freely advmod available ADJ []
# available acomp is AUX [freely]
# at prep is AUX [URL]
# this det URL NOUN []
# http compound URL NOUN []
# URL pobj at ADP [this, http]
#
# Dependency Parsing Tree:
# The dataset is freely available at this http URL
# ==================================================
# Constituency Parsing Tree:
# TensorFlow nsubj is AUX []
# is ROOT is AUX [TensorFlow, system, .]
# a det system NOUN []
# machine compound learning NOUN []
# learning compound system NOUN [machine]
# system attr is AUX [a, learning, operates]
# that nsubj operates VERB []
# operates relcl system NOUN [that, at]
# at prep operates VERB [scale, and, in]
# large amod scale NOUN []
# scale pobj at ADP [large]
# and cc at ADP []
# in conj at ADP [environment]
# heterogeneous amod environment NOUN []
# environment pobj in ADP [heterogeneous]
# . punct is AUX []
#
# Dependency Parsing Tree:
# TensorFlow is a machine learning system that operates at large scale and in heterogeneous environment .
# ==================================================
# Constituency Parsing Tree:
# Tensor compound Flow VERB []
# - punct Flow VERB []
# Flow ROOT Flow VERB [Tensor, -, graph, represent, ,, state, .]
# us nmod graph NOUN []
# dataflow amod graph NOUN []
# graph dobj Flow VERB [us, dataflow]
# to aux represent VERB []
# represent advcl Flow VERB [to, computation]
# computation dobj represent VERB []
# , punct Flow VERB []
# shared amod state NOUN []
# state npadvmod Flow VERB [shared, ,, and, operation]
# , punct state NOUN []
# and cc state NOUN []
# the det operation NOUN []
# operation conj state NOUN [the, mutate]
# that nsubj mutate VERB []
# mutate relcl operation NOUN [that, state]
# that det state NOUN []
# state dobj mutate VERB [that]
# . punct Flow VERB []
#
# Dependency Parsing Tree:
# Tensor-Flow us dataflow graph to represent computation , shared state , and the operation that mutate that state .
# ==================================================
# Constituency Parsing Tree:
# It nsubj map VERB []
# map ROOT map VERB [It, node, in, ,, and, within, .]
# the det node NOUN []
# node dobj map VERB [the, of]
# of prep node NOUN [graph]
# a det graph NOUN []
# dataflow amod graph NOUN []
# graph pobj of ADP [a, dataflow, across]
# across prep graph NOUN [machine]
# many amod machine NOUN []
# machine pobj across ADP [many]
# in prep map VERB [cluster]
# a det cluster NOUN []
# cluster pobj in ADP [a]
# , punct map VERB []
# and cc map VERB []
# within conj map VERB [machine]
# a det machine NOUN []
# machine pobj within ADP [a, across, ,, including]
# across prep machine NOUN [device]
# multiple amod device NOUN []
# computational amod device NOUN []
# device pobj across ADP [multiple, computational]
# , punct machine NOUN []
# including prep machine NOUN [CPUs]
# multicore amod CPUs PROPN []
# CPUs pobj including VERB [multicore, ,, GPUs, ,, and, ASICs, )]
# , punct CPUs PROPN []
# general amod purpose NOUN []
# - punct purpose NOUN []
# purpose compound GPUs NOUN [general, -]
# GPUs conj CPUs PROPN [purpose]
# , punct CPUs PROPN []
# and cc CPUs PROPN []
# custom advmod designed VERB []
# - punct designed VERB []
# designed amod ASICs NOUN [custom, -]
# ASICs conj CPUs PROPN [designed, known]
# known acl ASICs NOUN [Units]
# a det Units PROPN []
# Tensor compound Units PROPN []
# Processing compound Units PROPN []
# Units dobj known VERB [a, Tensor, Processing, (, TPUs]
# ( punct Units PROPN []
# TPUs appos Units PROPN []
# ) punct CPUs PROPN []
# . punct map VERB []
#
# Dependency Parsing Tree:
# It map the node of a dataflow graph across many machine in a cluster , and within a machine across multiple computational device , including multicore CPUs , general-purpose GPUs , and custom-designed ASICs known a Tensor Processing Units ( TPUs ) .
# ==================================================
# Constituency Parsing Tree:
# This det architecture NOUN []
# architecture nsubj give VERB [This]
# give ccomp enables VERB [architecture, flexibility, to, :]
# flexibility dobj give VERB []
# to dative give VERB [developer]
# the det developer NOUN []
# application compound developer NOUN []
# developer pobj to ADP [the, application]
# : punct give VERB []
# whereas mark built VERB []
# in prep built VERB [server, design]
# previous amod server PROPN []
# ` punct server PROPN []
# ` punct server PROPN []
# parameter nmod server PROPN []
# server pobj in ADP [previous, `, `, parameter, '']
# '' punct server PROPN []
# design pobj in ADP []
# the det management NOUN []
# management nsubjpass built VERB [the, of]
# of prep management NOUN [state]
# shared amod state NOUN []
# state pobj of ADP [shared]
# is auxpass built VERB []
# built advcl enables VERB [whereas, in, management, is, into]
# into prep built VERB [system]
# the det system NOUN []
# system pobj into ADP [the]
# , punct enables VERB []
# TensorFlow nsubj enables VERB []
# enables ROOT enables VERB [give, built, ,, TensorFlow, developer, to, .]
# developer dobj enables VERB []
# to prep enables VERB [experiment]
# experiment pobj to ADP [with]
# with prep experiment NOUN [optimization]
# novel amod optimization NOUN []
# optimization pobj with ADP [novel, and, algorithm]
# and cc optimization NOUN []
# training compound algorithm PROPN []
# algorithm conj optimization NOUN [training]
# . punct enables VERB []
#
# Dependency Parsing Tree:
# This architecture give flexibility to the application developer : whereas in previous `` parameter server '' design the management of shared state is built into the system , TensorFlow enables developer to experiment with novel optimization and training algorithm .
# ==================================================
# Constituency Parsing Tree:
# TensorFlow nsubj support VERB []
# support ROOT support VERB [TensorFlow, variety, ,, with, .]
# a det variety NOUN []
# variety dobj support VERB [a, of]
# of prep variety NOUN [application]
# application pobj of ADP []
# , punct support VERB []
# with prep support VERB [focus]
# a det focus NOUN []
# focus pobj with ADP [a, on]
# on prep focus NOUN [training]
# training pobj on ADP [and, inference, on]
# and cc training NOUN []
# inference conj training NOUN []
# on prep training NOUN [network]
# deep amod network NOUN []
# neural amod network NOUN []
# network pobj on ADP [deep, neural]
# . punct support VERB []
#
# Dependency Parsing Tree:
# TensorFlow support a variety of application , with a focus on training and inference on deep neural network .
# ==================================================
# Constituency Parsing Tree:
# Several amod service NOUN []
# Google compound service NOUN []
# service nsubj use VERB [Several, Google]
# use ccomp released VERB [service, TensorFlow, in]
# TensorFlow dobj use VERB []
# in prep use VERB [production]
# production pobj in ADP []
# , punct released VERB []
# we nsubj released VERB []
# have aux released VERB []
# released ROOT released VERB [use, ,, we, have, it, project, ,, and, used]
# it dobj released VERB []
# a det project NOUN []
# an det project NOUN []
# open amod source NOUN []
# - punct source NOUN []
# source compound project NOUN [open, -]
# project dobj released VERB [a, an, source]
# , punct released VERB []
# and cc released VERB []
# it nsubjpass used VERB []
# ha intj used VERB []
# become auxpass used VERB []
# widely advmod used VERB []
# used conj released VERB [it, ha, become, widely, for, .]
# for prep used VERB [research]
# machine compound learning VERB []
# learning compound research NOUN [machine]
# research pobj for ADP [learning]
# . punct used VERB []
#
# Dependency Parsing Tree:
# Several Google service use TensorFlow in production , we have released it a an open-source project , and it ha become widely used for machine learning research .
# ==================================================
# Constituency Parsing Tree:
# In prep describe VERB [paper]
# this det paper NOUN []
# paper pobj In ADP [this]
# , punct describe VERB []
# we nsubj describe VERB []
# describe ROOT describe VERB [In, ,, we, model, and, demonstrate, .]
# the det model NOUN []
# TensorFlow amod model NOUN []
# dataflow amod model NOUN []
# model dobj describe VERB [the, TensorFlow, dataflow]
# and cc describe VERB []
# demonstrate conj describe VERB [performance]
# the det performance NOUN []
# compelling amod performance NOUN []
# performance dobj demonstrate VERB [the, compelling, achieves]
# that dobj achieves VERB []
# TensorFlow nsubj achieves VERB []
# achieves relcl performance NOUN [that, TensorFlow, for]
# for prep achieves VERB [application]
# several amod application NOUN []
# real amod world NOUN []
# - punct world NOUN []
# world compound application NOUN [real, -]
# application pobj for ADP [several, world]
# . punct describe VERB []
#
# Dependency Parsing Tree:
# In this paper , we describe the TensorFlow dataflow model and demonstrate the compelling performance that TensorFlow achieves for several real-world application .
# ==================================================
#                                     lemmatized_abstract  noun  verb  adjective  adverb  \
# 0     We present Fashion-MNIST , a new dataset compr...    32     9          8       1
# 1     TensorFlow is a machine learning system that o...    63    25         17       2
# 2     TensorFlow is an interface for expressing mach...    64    28         19       1
# 3     The goal of precipitation nowcasting is to pre...    43    18         16       5
# 4                                                   NaN     0     0          0       0
# ...                                                 ...   ...   ...        ...     ...
# 9995  Artificial Intelligence : Foundations of Compu...    46    18         18       4
# 9996                                                NaN     0     0          0       0
# 9997                                                NaN     0     0          0       0
# 9998                                                NaN     0     0          0       0
# 9999  Updated and expanded , Bayesian Artificial Int...    91    27         28       1
#
#                                                entities
# 0     [28x28 - CARDINAL, 70,000 - CARDINAL, 10 - CAR...
# 1     [TensorFlow - ORG, ASICs - ORG, Tensor Process...
# 2     [TensorFlow - PRODUCT, TensorFlow - PRODUCT, h...
# 3                          [FC-LSTM - ORG, ROVER - ORG]
# 4                                                    []
# ...                                                 ...
# 9995  [AI - ORG, AI - ORG, The past decade - DATE, A...
# 9996                                                 []
# 9997                                                 []
# 9998                                                 []
# 9999  [Bayesian Artificial Intelligence - ORG, Secon...
#
# [10000 rows x 6 columns]

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below

I find it so challenging as we need to concentrate more on web scraping the different websites using python.
I enjoyed trying to solve all the other sites for web scraping so that i can get more handson experience on web scraping any website.
The stemming and lemmatization parts are funny as the words are not completely replaced when we do stemming process.
The time provided is enough to complete the assignment .
